# %% [markdown]
# # Web Scraper
# - Beautiful Soup: https://realpython.com/beautiful-soup-web-scraper-python/

# %%
import pandas as pd
import time, datetime
import multiprocessing as mp
from datetime import datetime as dt
import math

# %% [markdown]
# ## Load Data

# %%
bad_cols = [0,2,6,15,16,17,18,19,20,21,22,24,25,26] # unnecessary columns from example_data notebook
cols = list(range(0,26)) # list of all columns
good_cols = [i for i in cols if i not in bad_cols] # create list of useful columns
good_cols = [str(x) for x in good_cols] # convert to string
good_cols
# Out:
# ['1', '3', '4', '5', '7', '8', '9', '10', '11', '12', '13', '14', '23']

# %%
start = time.time()
# read data in chunks of 100k rows at a time
chunk = pd.read_csv('../00-data/gdelt_data/2021/gdelt_sum_dec2021.csv.zip', 
                    chunksize=100000, 
                    dtype={'3': 'str'})#, # mixed data types
                    #index_col=[0]) # specify index column
# iter_csv = pd.read_csv('file.csv', iterator=True, chunksize=1000)
# df = pd.concat([chunk[chunk['field'] > constant] for chunk in iter_csv])
df = pd.concat(chunk) # concat chunks together
end = time.time()
print("Read csv with chunks: ",(end-start),"sec")
# Out:
# Read csv with chunks:  6.2673890590667725 sec

# %%
df
# Out:
#                      1                     3  \
# 0       20211201000000      mcdowellnews.com
# 1       20211201000000           observer.ug
# 2       20211201000000            menafn.com
# 3       20211201000000           hot1063.com
# 4       20211201000000      altenergymag.com
# ...                ...                   ...
# 150669  20211201234500      freightwaves.com
# 150670  20211201234500  newyorktelegraph.com
# 150671  20211201234500     dailyrecord.co.uk
# 150672  20211201234500              scmp.com
# 150673  20211201234500           binnews.com
#
#                                                         4  \
# 0       https://mcdowellnews.com/news/national/govt-an...
# 1       https://www.observer.ug/viewpoint/72021-why-sh...
# 2       https://menafn.com/1103282515/9-injured-in-ref...
# 3       https://www.hot1063.com/news/red-notice-is-now...
# 4       https://www.altenergymag.com/company_directory...
# ...                                                   ...
# 150669  https://www.freightwaves.com/news/thanksgiving...
# 150670  https://www.newyorktelegraph.com/news/27184719...
# 150671  https://www.dailyrecord.co.uk/lifestyle/warnin...
# 150672  https://www.scmp.com/news/china/diplomacy/arti...
# 150673  https://dayton.binnews.com/content/2021-12-01-...
#
#                                                         5  \
# 0                                                     NaN
# 1                                                     NaN
# 2       WOUND#9##1#Algeria#AG#AG#28#3#AG;CRISISLEX_CRI...
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 150669                                                NaN
# 150670                                                NaN
# 150671                                                NaN
# 150672                                                NaN
# 150673  KILL#2##3#Kenosha, Wisconsin, United States#US...
#
#                                                         7  \
# 0                                                     NaN
# 1       GENERAL_GOVERNMENT;EPU_POLICY;EPU_POLICY_GOVER...
# 2       WOUND;CRISISLEX_CRISISLEXREC;CRISISLEX_C03_WEL...
# 3       CRIME_COMMON_ROBBERY;TAX_FNCACT;TAX_FNCACT_THI...
# 4                                              ENV_SOLAR;
# ...                                                   ...
# 150669  NEGOTIATIONS;GEN_HOLIDAY;USPEC_POLICY1;EPU_POL...
# 150670  TAX_FNCACT;TAX_FNCACT_WORKERS;USPEC_POLICY1;EP...
# 150671  TAX_WORLDMAMMALS;TAX_WORLDMAMMALS_DOG;TAX_WORL...
# 150672  GENERAL_HEALTH;MEDICAL;CRISISLEX_C07_SAFETY;UN...
# 150673  WB_678_DIGITAL_GOVERNMENT;WB_694_BROADCAST_AND...
#
#                                                         8  \
# 0                                                     NaN
# 1       WB_178_PEST_MANAGEMENT,4266;WB_174_CROP_PRODUC...
# 2       LEADER,524;ENV_OIL,96;ENV_MINING,539;DISASTER_...
# 3       CRIME_COMMON_ROBBERY,727;TAX_FNCACT_THIEF,727;...
# 4       ENV_SOLAR,75;ENV_SOLAR,313;ENV_SOLAR,353;ENV_S...
# ...                                                   ...
# 150669  GEN_HOLIDAY,523;GEN_HOLIDAY,1080;GEN_HOLIDAY,1...
# 150670  GENERAL_GOVERNMENT,212;EPU_POLICY_GOVERNMENT,2...
# 150671  AGRICULTURE,4612;WB_1467_EDUCATION_FOR_ALL,307...
# 150672  UNGP_FORESTS_RIVERS_OCEANS,115;GENERAL_HEALTH,...
# 150673  WB_696_PUBLIC_SECTOR_MANAGEMENT,988;WB_840_JUS...
#
#                                                         9  \
# 0       2#Alaska, United States#US#USAK#61.385#-152.26...
# 1                                  1#Uganda#UG#UG#2#33#UG
# 2       4#Skikda, Wilaya De Skikda, Algeria#AG#AG31#36...
# 3                                                     NaN
# 4             1#United States#US#US#39.828175#-98.5795#US
# ...                                                   ...
# 150669  1#United States#US#US#39.828175#-98.5795#US;3#...
# 150670  1#Germany#GM#GM#51.5#10.5#GM;4#Paris, France (...
# 150671  1#Sweden#SW#SW#62#15#SW;1#United Kingdom#UK#UK...
# 150672                            1#China#CH#CH#35#105#CH
# 150673  3#Kenosha, Wisconsin, United States#US#USWI#42...
#
#                                                        10  \
# 0       2#Alaskans, United States#US#USAK##61.385#-152...
# 1       1#Uganda#UG#UG##2#33#UG#204;1#Uganda#UG#UG##2#...
# 2       4#Skikda, Wilaya De Skikda, Algeria#AG#AG31#38...
# 3                                                     NaN
# 4       1#America#US#US##39.828175#-98.5795#US#626;1#U...
# ...                                                   ...
# 150669  2#Texas, United States#US#USTX##31.106#-97.647...
# 150670  4#Petersburg, Sankt-Peterburg, Russia#RS#RS66#...
# 150671  1#United Kingdom#UK#UK##54#-4#UK#202;1#United ...
# 150672                        1#China#CH#CH##35#105#CH#23
# 150673  2#Wisconsin, United States#US#USWI##44.2563#-8...
#
#                                                        11  \
# 0                         mike dunleavy;christine oconnor
# 1                                        isabella akiteng
# 2                                           mohamed arkab
# 3                  gal gadot;ryan reynolds;dwayne johnson
# 4                                                     NaN
# ...                                                   ...
# 150669                 los angeles;kevin hill;tony mulvey
# 150670                         peng shuai;queen elizabeth
# 150671                                   carolyn menteith
# 150672                                                NaN
# 150673  corey chirafisi;jacob blake;kyle rittenhouse;e...
#
#                                                        12  \
# 0                 Mike Dunleavy,586;Christine Oconnor,256
# 1                                    Isabella Akiteng,949
# 2                                       Mohamed Arkab,553
# 3       Gal Gadot,417;Ryan Reynolds,405;Dwayne Johnson,14
# 4                                                     NaN
# ...                                                   ...
# 150669  Los Angeles,9113;Los Angeles,12066;Los Angeles...
# 150670                 Peng Shuai,599;Queen Elizabeth,752
# 150671                               Carolyn Menteith,872
# 150672                                                NaN
# 150673  Corey Chirafisi,810;Jacob Blake,1094;Kyle Ritt...
#
#                                                        13  \
# 0                              alaska telecom association
# 1       friedrich ebert stiftung youth leaders program...
# 2       sonatrach;menafn- trend news agency;sonatrach ...
# 3       netflix;warnermedia company;cable news network...
# 4       company sector;free company listing;company ca...
# ...                                                   ...
# 150669  walmart;freightwaves freight intel group;rate ...
# 150670     women tennis association;international section
# 150671                                                NaN
# 150672                                            reuters
# 150673                               princeton university
#
#                                                        14  \
# 0                          Alaska Telecom Association,205
# 1       Friedrich Ebert Stiftung Youth Leaders Program...
# 2       Sonatrach,295;Sonatrach,344;Sonatrach,714;Mena...
# 3       Netflix,147;Netflix,251;Netflix,607;Warnermedi...
# 4       Company Sector,785;Free Company Listing,901;Co...
# ...                                                   ...
# 150669  Walmart,3452;Freightwaves Freight Intel Group,...
# 150670  Women Tennis Association,522;International Sec...
# 150671                                                NaN
# 150672                                        Reuters,160
# 150673                          Princeton University,1780
#
#                                                        23
# 0        Alaska Telecom Association,225;Mike Dunleavy,616
# 1       Friedrich Ebert Stiftung,902;Youth Leaders,917...
# 2       News Agency,23;Sonatrach Group,299;Algerian Mi...
# 3       Dwayne Johnson,15;Sandra Bullock,340;Ryan Reyn...
# 4       Project Development Support,94;Pima Center Pkw...
# ...                                                   ...
# 150669  Chain Pricing Power Index,46;Chain Pricing Pow...
# 150670  Tennis Association,529;Peng Shuai,612;Queen El...
# 150671  United Kingdom,215;Agria Pet,282;Team Dogs,323...
# 150672                                                NaN
# 150673  Kyle Rittenhouse,17;Charlie Kirk,98;Fox News,1...
#
# [150674 rows x 13 columns]

# %%
type(df['1'][0])
# Out:
# str

# %%
bad_rows = df[~df['1'].str.get(0).isin(['2'])].index # remove rows with dates that don't start with 2
bad_rows = bad_rows.append(df[~df['1'].str.get(1).isin(['0'])].index) # remove rows with dates second number isn't 0
df = df.drop(index = bad_rows)
df['1'] = [int(float(i)) for i in df['1']]
df
# Out:
#                      1                     3  \
# 0       20211201000000      mcdowellnews.com
# 1       20211201000000           observer.ug
# 2       20211201000000            menafn.com
# 3       20211201000000           hot1063.com
# 4       20211201000000      altenergymag.com
# ...                ...                   ...
# 150669  20211201234500      freightwaves.com
# 150670  20211201234500  newyorktelegraph.com
# 150671  20211201234500     dailyrecord.co.uk
# 150672  20211201234500              scmp.com
# 150673  20211201234500           binnews.com
#
#                                                         4  \
# 0       https://mcdowellnews.com/news/national/govt-an...
# 1       https://www.observer.ug/viewpoint/72021-why-sh...
# 2       https://menafn.com/1103282515/9-injured-in-ref...
# 3       https://www.hot1063.com/news/red-notice-is-now...
# 4       https://www.altenergymag.com/company_directory...
# ...                                                   ...
# 150669  https://www.freightwaves.com/news/thanksgiving...
# 150670  https://www.newyorktelegraph.com/news/27184719...
# 150671  https://www.dailyrecord.co.uk/lifestyle/warnin...
# 150672  https://www.scmp.com/news/china/diplomacy/arti...
# 150673  https://dayton.binnews.com/content/2021-12-01-...
#
#                                                         5  \
# 0                                                     NaN
# 1                                                     NaN
# 2       WOUND#9##1#Algeria#AG#AG#28#3#AG;CRISISLEX_CRI...
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 150669                                                NaN
# 150670                                                NaN
# 150671                                                NaN
# 150672                                                NaN
# 150673  KILL#2##3#Kenosha, Wisconsin, United States#US...
#
#                                                         7  \
# 0                                                     NaN
# 1       GENERAL_GOVERNMENT;EPU_POLICY;EPU_POLICY_GOVER...
# 2       WOUND;CRISISLEX_CRISISLEXREC;CRISISLEX_C03_WEL...
# 3       CRIME_COMMON_ROBBERY;TAX_FNCACT;TAX_FNCACT_THI...
# 4                                              ENV_SOLAR;
# ...                                                   ...
# 150669  NEGOTIATIONS;GEN_HOLIDAY;USPEC_POLICY1;EPU_POL...
# 150670  TAX_FNCACT;TAX_FNCACT_WORKERS;USPEC_POLICY1;EP...
# 150671  TAX_WORLDMAMMALS;TAX_WORLDMAMMALS_DOG;TAX_WORL...
# 150672  GENERAL_HEALTH;MEDICAL;CRISISLEX_C07_SAFETY;UN...
# 150673  WB_678_DIGITAL_GOVERNMENT;WB_694_BROADCAST_AND...
#
#                                                         8  \
# 0                                                     NaN
# 1       WB_178_PEST_MANAGEMENT,4266;WB_174_CROP_PRODUC...
# 2       LEADER,524;ENV_OIL,96;ENV_MINING,539;DISASTER_...
# 3       CRIME_COMMON_ROBBERY,727;TAX_FNCACT_THIEF,727;...
# 4       ENV_SOLAR,75;ENV_SOLAR,313;ENV_SOLAR,353;ENV_S...
# ...                                                   ...
# 150669  GEN_HOLIDAY,523;GEN_HOLIDAY,1080;GEN_HOLIDAY,1...
# 150670  GENERAL_GOVERNMENT,212;EPU_POLICY_GOVERNMENT,2...
# 150671  AGRICULTURE,4612;WB_1467_EDUCATION_FOR_ALL,307...
# 150672  UNGP_FORESTS_RIVERS_OCEANS,115;GENERAL_HEALTH,...
# 150673  WB_696_PUBLIC_SECTOR_MANAGEMENT,988;WB_840_JUS...
#
#                                                         9  \
# 0       2#Alaska, United States#US#USAK#61.385#-152.26...
# 1                                  1#Uganda#UG#UG#2#33#UG
# 2       4#Skikda, Wilaya De Skikda, Algeria#AG#AG31#36...
# 3                                                     NaN
# 4             1#United States#US#US#39.828175#-98.5795#US
# ...                                                   ...
# 150669  1#United States#US#US#39.828175#-98.5795#US;3#...
# 150670  1#Germany#GM#GM#51.5#10.5#GM;4#Paris, France (...
# 150671  1#Sweden#SW#SW#62#15#SW;1#United Kingdom#UK#UK...
# 150672                            1#China#CH#CH#35#105#CH
# 150673  3#Kenosha, Wisconsin, United States#US#USWI#42...
#
#                                                        10  \
# 0       2#Alaskans, United States#US#USAK##61.385#-152...
# 1       1#Uganda#UG#UG##2#33#UG#204;1#Uganda#UG#UG##2#...
# 2       4#Skikda, Wilaya De Skikda, Algeria#AG#AG31#38...
# 3                                                     NaN
# 4       1#America#US#US##39.828175#-98.5795#US#626;1#U...
# ...                                                   ...
# 150669  2#Texas, United States#US#USTX##31.106#-97.647...
# 150670  4#Petersburg, Sankt-Peterburg, Russia#RS#RS66#...
# 150671  1#United Kingdom#UK#UK##54#-4#UK#202;1#United ...
# 150672                        1#China#CH#CH##35#105#CH#23
# 150673  2#Wisconsin, United States#US#USWI##44.2563#-8...
#
#                                                        11  \
# 0                         mike dunleavy;christine oconnor
# 1                                        isabella akiteng
# 2                                           mohamed arkab
# 3                  gal gadot;ryan reynolds;dwayne johnson
# 4                                                     NaN
# ...                                                   ...
# 150669                 los angeles;kevin hill;tony mulvey
# 150670                         peng shuai;queen elizabeth
# 150671                                   carolyn menteith
# 150672                                                NaN
# 150673  corey chirafisi;jacob blake;kyle rittenhouse;e...
#
#                                                        12  \
# 0                 Mike Dunleavy,586;Christine Oconnor,256
# 1                                    Isabella Akiteng,949
# 2                                       Mohamed Arkab,553
# 3       Gal Gadot,417;Ryan Reynolds,405;Dwayne Johnson,14
# 4                                                     NaN
# ...                                                   ...
# 150669  Los Angeles,9113;Los Angeles,12066;Los Angeles...
# 150670                 Peng Shuai,599;Queen Elizabeth,752
# 150671                               Carolyn Menteith,872
# 150672                                                NaN
# 150673  Corey Chirafisi,810;Jacob Blake,1094;Kyle Ritt...
#
#                                                        13  \
# 0                              alaska telecom association
# 1       friedrich ebert stiftung youth leaders program...
# 2       sonatrach;menafn- trend news agency;sonatrach ...
# 3       netflix;warnermedia company;cable news network...
# 4       company sector;free company listing;company ca...
# ...                                                   ...
# 150669  walmart;freightwaves freight intel group;rate ...
# 150670     women tennis association;international section
# 150671                                                NaN
# 150672                                            reuters
# 150673                               princeton university
#
#                                                        14  \
# 0                          Alaska Telecom Association,205
# 1       Friedrich Ebert Stiftung Youth Leaders Program...
# 2       Sonatrach,295;Sonatrach,344;Sonatrach,714;Mena...
# 3       Netflix,147;Netflix,251;Netflix,607;Warnermedi...
# 4       Company Sector,785;Free Company Listing,901;Co...
# ...                                                   ...
# 150669  Walmart,3452;Freightwaves Freight Intel Group,...
# 150670  Women Tennis Association,522;International Sec...
# 150671                                                NaN
# 150672                                        Reuters,160
# 150673                          Princeton University,1780
#
#                                                        23
# 0        Alaska Telecom Association,225;Mike Dunleavy,616
# 1       Friedrich Ebert Stiftung,902;Youth Leaders,917...
# 2       News Agency,23;Sonatrach Group,299;Algerian Mi...
# 3       Dwayne Johnson,15;Sandra Bullock,340;Ryan Reyn...
# 4       Project Development Support,94;Pima Center Pkw...
# ...                                                   ...
# 150669  Chain Pricing Power Index,46;Chain Pricing Pow...
# 150670  Tennis Association,529;Peng Shuai,612;Queen El...
# 150671  United Kingdom,215;Agria Pet,282;Team Dogs,323...
# 150672                                                NaN
# 150673  Kyle Rittenhouse,17;Charlie Kirk,98;Fox News,1...
#
# [150571 rows x 13 columns]

# %%
filter_df = df[df['3']=='yahoo.com']
filter_df
# Out:
#                      1          3  \
# 25      20211201000000  yahoo.com
# 72      20211201000000  yahoo.com
# 171     20211201000000  yahoo.com
# 173     20211201000000  yahoo.com
# 176     20211201000000  yahoo.com
# ...                ...        ...
# 150224  20211201234500  yahoo.com
# 150332  20211201234500  yahoo.com
# 150372  20211201234500  yahoo.com
# 150452  20211201234500  yahoo.com
# 150572  20211201234500  yahoo.com
#
#                                                         4    5  \
# 25      https://finance.yahoo.com/news/shareholder-ale...  NaN
# 72      https://news.yahoo.com/something-really-sweet-...  NaN
# 171     https://news.yahoo.com/myles-gaskin-230745925....  NaN
# 173     https://news.yahoo.com/lawsuit-alleges-marylan...  NaN
# 176     https://finance.yahoo.com/news/shareholder-ale...  NaN
# ...                                                   ...  ...
# 150224  https://au.news.yahoo.com/coral-rubble-threat-...  NaN
# 150332  https://it.notizie.yahoo.com/vaccino-covid-pfi...  NaN
# 150372  https://news.yahoo.com/stc-gets-4-programs-2-2...  NaN
# 150452  https://finance.yahoo.com/news/over-billion-vo...  NaN
# 150572  https://es.noticias.yahoo.com/espa%C3%B1a-suma...  NaN
#
#                                                         7  \
# 25      EPU_CATS_REGULATION;WB_1921_PRIVATE_SECTOR_DEV...
# 72      TAX_ETHNICITY;TAX_ETHNICITY_AMERICAN;NATURAL_D...
# 171     EPU_CATS_REGULATION;WB_1921_PRIVATE_SECTOR_DEV...
# 173     EPU_CATS_REGULATION;WB_1921_PRIVATE_SECTOR_DEV...
# 176     EPU_CATS_REGULATION;WB_1921_PRIVATE_SECTOR_DEV...
# ...                                                   ...
# 150224  KILL;CRISISLEX_CRISISLEXREC;CRISISLEX_T02_INJU...
# 150332  EPU_CATS_REGULATION;WB_1921_PRIVATE_SECTOR_DEV...
# 150372  EDUCATION;SOC_POINTSOFINTEREST;SOC_POINTSOFINT...
# 150452                  TAX_FNCACT;TAX_FNCACT_VOLUNTEERS;
# 150572  EPU_CATS_REGULATION;WB_1921_PRIVATE_SECTOR_DEV...
#
#                                                         8  \
# 25      SOC_EMERGINGTECH,749;EPU_CATS_REGULATION,350;E...
# 72      TAX_FNCACT_DEPUTY,2991;MEDIA_SOCIAL,1634;TAX_F...
# 171     SOC_EMERGINGTECH,1017;EPU_CATS_REGULATION,618;...
# 173     SOC_EMERGINGTECH,1017;EPU_CATS_REGULATION,618;...
# 176     SOC_EMERGINGTECH,749;EPU_CATS_REGULATION,350;E...
# ...                                                   ...
# 150224  TAX_FNCACT_PROFESSOR,514;SOC_POINTSOFINTEREST_...
# 150332  SOC_EMERGINGTECH,1017;EPU_CATS_REGULATION,618;...
# 150372  TAX_FNCACT_ASSISTANT,1828;EDUCATION,27;EDUCATI...
# 150452                          TAX_FNCACT_VOLUNTEERS,58;
# 150572  SOC_EMERGINGTECH,1017;EPU_CATS_REGULATION,618;...
#
#                                                         9  \
# 25                                                    NaN
# 72      1#China#CH#CH#35#105#CH;2#Florida, United Stat...
# 171                                                   NaN
# 173                                                   NaN
# 176                                                   NaN
# ...                                                   ...
# 150224  1#Australia#AS#AS#-25#135#AS;4#Great Barrier R...
# 150332                                                NaN
# 150372  3#Sioux Falls, South Dakota, United States#US#...
# 150452                                                NaN
# 150572                                                NaN
#
#                                                        10  \
# 25                                                    NaN
# 72      3#Mayport, Florida, United States#US#USFL#FL03...
# 171                                                   NaN
# 173                                                   NaN
# 176                                                   NaN
# ...                                                   ...
# 150224  4#Great Barrier Reef, Queensland, Australia#AS...
# 150332                                                NaN
# 150372  3#Sioux Falls, South Dakota, United States#US#...
# 150452                                                NaN
# 150572                                                NaN
#
#                                                        11  \
# 25      jake archibald;yehuda katz;stefan penner;tom dale
# 72      ann singleton;michael phillips;guy fieri;gary ...
# 171     jake archibald;yehuda katz;stefan penner;tom dale
# 173     jake archibald;yehuda katz;stefan penner;tom dale
# 176     jake archibald;yehuda katz;stefan penner;tom dale
# ...                                                   ...
# 150224                            tania kenyon;sussan ley
# 150332  jake archibald;yehuda katz;stefan penner;tom dale
# 150372                                                NaN
# 150452                                                NaN
# 150572  jake archibald;yehuda katz;stefan penner;tom dale
#
#                                                        12  \
# 25      Jake Archibald,458;Yehuda Katz,376;Stefan Penn...
# 72      Ann Singleton,1922;Michael Phillips,1135;Guy F...
# 171     Jake Archibald,726;Yehuda Katz,644;Stefan Penn...
# 173     Jake Archibald,726;Yehuda Katz,644;Stefan Penn...
# 176     Jake Archibald,458;Yehuda Katz,376;Stefan Penn...
# ...                                                   ...
# 150224                  Tania Kenyon,1973;Sussan Ley,3307
# 150332  Jake Archibald,726;Yehuda Katz,644;Stefan Penn...
# 150372                                                NaN
# 150452                                                NaN
# 150572  Jake Archibald,726;Yehuda Katz,644;Stefan Penn...
#
#                                                        13  \
# 25                                                    NaN
# 72      fresh mex co;johns town center;twitter;food ne...
# 171                                                   NaN
# 173                                                   NaN
# 176                                                   NaN
# ...                                                   ...
# 150224  university of queensland professor peter mumby...
# 150332                                                NaN
# 150372  technical education academy;huron community ce...
# 150452                                                NaN
# 150572                                                NaN
#
#                                                        14  \
# 25                                                    NaN
# 72      Fresh Mex Co,595;Johns Town Center,560;Twitter...
# 171                                                   NaN
# 173                                                   NaN
# 176                                                   NaN
# ...                                                   ...
# 150224  University Of Queensland Professor Peter Mumby...
# 150332                                                NaN
# 150372  Technical Education Academy,666;Huron Communit...
# 150452                                                NaN
# 150572                                                NaN
#
#                                                        23
# 25      Tom Dale,450;Stefan Penner,469;Jake Archibald,528
# 72      With Thanksgiving,18;Sugar Factory American Br...
# 171     Tom Dale,798;Stefan Penner,817;Jake Archibald,876
# 173     Tom Dale,798;Stefan Penner,817;Jake Archibald,876
# 176     Tom Dale,450;Stefan Penner,469;Jake Archibald,528
# ...                                                   ...
# 150224  Great Barrier Reef,74;Queensland Professor Pet...
# 150332  Tom Dale,798;Stefan Penner,817;Jake Archibald,876
# 150372  Southeast Technical College,28;Higher Learning...
# 150452                                                NaN
# 150572  Tom Dale,798;Stefan Penner,817;Jake Archibald,876
#
# [2681 rows x 13 columns]

# %%
filter_urls = filter_df['4']
filter_urls
# Out:
# 25        https://finance.yahoo.com/news/shareholder-ale...
# 72        https://news.yahoo.com/something-really-sweet-...
# 171       https://news.yahoo.com/myles-gaskin-230745925....
# 173       https://news.yahoo.com/lawsuit-alleges-marylan...
# 176       https://finance.yahoo.com/news/shareholder-ale...
#                                 ...
# 150224    https://au.news.yahoo.com/coral-rubble-threat-...
# 150332    https://it.notizie.yahoo.com/vaccino-covid-pfi...
# 150372    https://news.yahoo.com/stc-gets-4-programs-2-2...
# 150452    https://finance.yahoo.com/news/over-billion-vo...
# 150572    https://es.noticias.yahoo.com/espa%C3%B1a-suma...
# Name: 4, Length: 2681, dtype: object

# %%
filter_urls.iloc[1]
# Out:
# 'https://news.yahoo.com/something-really-sweet-headed-way-224350769.html'

# %% [markdown]
# ## Beautiful Soup

# %%
from bs4 import BeautifulSoup
import requests

URL = filter_urls.iloc[1]
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
master = soup.find(id="Masterwrap2Col")
print(master.prettify())
# Out:
# <div class="W(100%) Pos(r) Op(1) Reader-open_Op(0) Trs($pageTransition)" id="Masterwrap2Col">
#  <span id="close-fauxdal">
#   <a class="Bgc(#fff) Cur(p) Pos(f) Start(0) End(0) T(0) B(0)" data-ylk="sec:hl-viewer;itc:0;slk:close-wrapper;_p:1;tar:news.yahoo.com;tar_uri:/;elm:wrapper" href="https://news.yahoo.com">
#   </a>
#  </span>
#  <div class="page-wrapper D(f)! Fld(r) Fxw(w) Jc(sb) Ai(fs) Z(1) Pos(r) Maw(1260px) Miw(980px) Miw(a)--md Mx(a)" id="Page">
#   <main class="W(100%) Px(20px) D(f)! Maw(1260px) Miw(980px) Mx(a) Z(0) wafer-sticky" data-wf-sticky-boundary="page-wrapper" data-wf-sticky-offset="160px" data-wf-sticky-target=".close-button-wrapper" role="main">
#    <div class="close-button-wrapper Pos(a) W(60px) H(60px) Mt(10px) End(a)!--miw1350 End(20px) Z(10) Mstart(1222px)!" id="close-button-section">
#     <div class="close-button-inner Pos(a) W(50px) H(50px) D(f) Ai(c) Jc(c) Bgc(#fff) Z(1) Bdrs(50%) Bxsh($closeButtonShadow) Bd(1px) Bdc(t) Bds(s)">
#      <a class="Z(1)" data-ylk="sec:hl-viewer;itc:0;slk:close;_p:1;tar:www.yahoo.com;tar_uri:/" href="https://news.yahoo.com">
#       <svg class="Cur(p) Fill(#1d2228) close-button-inner:h_Fill(#6001d2) Va(b)" height="30" style="-mox-transform:translateX(-1px);" viewbox="-1 -1 50 50" width="30">
#        <path d="M37.98 34.827l-9.9-9.9 9.9-9.898c.78-.782.78-2.05 0-2.83-.78-.78-2.047-.78-2.828 0l-9.9 9.9-9.898-9.9c-.78-.78-2.048-.78-2.828 0-.78.78-.78 2.047 0 2.828l9.9 9.9-9.9 9.898c-.78.78-.78 2.047 0 2.828.78.78 2.047.78 2.828 0l9.9-9.9 9.898 9.9c.78.78 2.048.78 2.828 0 .782-.78.782-2.047 0-2.827z">
#        </path>
#       </svg>
#       <b class="Td(n) Hidden">
#        Close this content
#       </b>
#      </a>
#      <div class="wafer-progress-loader wafer-caas-progress-loader Pos(a) W(100%) H(100%)" data-wf-direction="both" data-wf-iteration-count="infinite" data-wf-line-width="2" data-wf-stroke-color="#7759ff" data-wf-target="#module-article" data-wf-type="circle">
#      </div>
#     </div>
#    </div>
#    <script type="text/javascript">
#     function onEscape(e) {
#         if (!e.defaultPrevented && e.keyCode === 27) {
#             window.location.href = closeUrl;
#         }
#     }
#     window.addEventListener('keyup', onEscape);
#    </script>
#    <div class="W($mainColWidth) Mend($gridMargin)">
#     <div id="caas-content-body">
#      <div id="content-wrapper">
#       <div>
#        <div id="module-article">
#         <div class="caas caas-cc enableInArticleAd enableLiveConfig enableSlideShowKV enableVideoDocking enableVideoThirtyView enableXrayEntityAboutFacts enableXrayNcp enableXrayNcpV2SalienceMerge enableXrayPeopleEntities enableXrayTopicEntities noRapidClickClass outStream removeDuplicateImage slideshowv2 news" data-assets="[]" data-cobrandname="" data-device="desktop" data-i18n='{"{0} min":"{0} min","{0} min read":"{0} min read","{0} mins read":"{0} mins read","{0} Views":"{0} Views","{0} followers":"{0} followers","{0} symbols":"{0} symbols","360_TITLE":"The 360","Ad":"Ad","AD_PLACEHOLDER_TEXT":"Advertisement","AND":"and","AR_INLINE_FALLBACK":"This story has augmented reality! Tap the video above to see how it looks and download the \u003Ca href=\"https:\u002F\u002Fitunes.apple.com\u002Fus\u002Fapp\u002Fyahoo-news-live-breaking-news\u002Fid304158842?mt=8\"\u003EYahoo News app\u003C\u002Fa\u003E to launch the full experience. Augmented reality is currently available to iPhone users (iPhone 8 and later) with the latest version of iOS.","AR_INTRO_LINK":"Read more about how it works here.","AR_INTRO":"Yahoo News now features augmented reality, an immersive storytelling format that brings our journalism to life in new ways. Experience it below.","AR_TITLE_MODEL_VIEWER":"Tap to see in your space &amp;rarr;","BUY_NOW":"Buy Now","CLOSE":"Close","CLOSE_TOOLTIP":"Close tooltip","CLOSE_XRAY_MODAL":"Close more info modal dialog","COLLAPSE":"Collapse","COMMENTS":"Comments","CONS":"Cons","CONSENT_BLOCKED_3P":"This content is not available due to your privacy preferences.","CONSENT_BLOCKED_3P_LINK_TEXT":"Update your settings here to see it.","CONTINUE_READING":"Continue reading","EMAIL":"Email","ENGADGET_DISCLAIMER":"All products recommended by Engadget are selected by our editorial team, independent of our parent company. Some of our stories include affiliate links. If you buy something through one of these links, we may earn an affiliate commission.","EXPLORE_THE_TOPICS":"Explore the topics mentioned in this article","FACT_CHECK":"Fact Check","FOLLOW":"Follow","GET_APP":"Get the App","GRAPHIQ":"Visualization by Graphiq","IN_THIS_ARTICLE":"In this article","LESS":"Less","LIVE":"Live","MORE":"More","MORE_CONTENT_BELOW":"More content below","NEW":"New","NEWS_APP_PROMOTION_CAPTION":"Stay in the know at a glance with the Top 10 daily stories","NEWS_APP_PROMOTION_HEADLINE":"Yahoo News is better in the app","NEXT_PHOTO":"Next photo","OOPS":"Oops!","OPEN_XRAY_MODAL":"More info modal dialog","ORIGINALLY_PUBLISHED":"Originally published","PHOTOS":"Photos","PIN_IT":"Pin it","POWERED_BY_YAHOO_FINANCE":"Powered by Yahoo Finance","PROS":"Pros","PREVIOUS_PHOTO":"Previous photo","PUBLISHED":"Published","PUBLISHER_ATTRIBUTION":"View article source","REACTIONS":"Reactions","READ_FULL_ARTICLE":"Read full article","READ_MORE":"Read More","RECIPE_DIRECTION_TITLE":"Directions","RECIPE_INGREDIENTS_TITLE":"Ingredients","Scroll to continue with content":"Scroll to continue with content","SEE_GALLERY":"See Gallery","SEE_LESS":"See less","SEE_MORE":"See more","SHARE_FACEBOOK":"Share on Facebook","SHARE_LINKEDIN":"Share on LinkedIn","SHARE_REDDIT":"Share on Reddit","SHARE_LINE":"Share on Line","SHARE_WHATSAPP":"Share on WhatsApp","SHARE":"Share","SHARES":"Shares","SHOW_MEDIA":"Show media","SHOW_NEXT_CARDS":"Show next cards","SHOW_PREVIOUS_CARDS":"Show previous cards","SHOW_TEXT_ONLY":"Show text only","SLIDE {0} OF {1}":"Slide {0} of {1}","SOMETHING_WENT_WRONG":"Something went wrong.","STORY_CONTINUES":"Story continues","STRUCTURED_SUMMARY_TITLE":"Summary","STRUCTURED_SUMMARY_TOOLTIP_TEXT":"Smart Summary powered by Yahoo, available on select stories.","SUMMARY":"Summary","SWIPE_DOWN_TO_CLOSE":"Swipe down to close.","TAGS":"Tags","TODAY":"Today","TOMORROW":"Tomorrow","TRY_LATER":"Please try again later.","TWEET":"Tweet","UNFOLLOW":"Unfollow","UNIT_OF_TIME_HOUR":"hr","UNIT_OF_TIME_MINUTE":"min","UPDATED":"Updated","VIDEO_TITLE":" [Video]","VIDEO_TRANSCRIPT":"Video Tra ...
#          <article class="caas-container" role="article" tabindex="-1">
#           <script type="application/ld+json">
#            {"@context":"http://schema.org","@type":"NewsArticle","mainEntityOfPage":"https://www.jacksonville.com/story/nletter/dining-notes/2021/11/30/something-really-sweet-headed-way/8800878002/","headline":"Something (really) sweet is headed this way","datePublished":"2021-12-01T14:33:12.000Z","dateModified":"2021-12-01T15:16:24.024Z","keywords":["turkey leftovers","Michael Phillips","Sugar Factory American Brasserie","Jacksonville Beach","Jacksonville","Ann Singleton","St. Johns Town Center","Couture Pops"],"description":"In this week's Dining Notes, look for news on Sugar Factory American Brasserie, Fresh Mex & Co., Huey Magoo's, Singleton's, Firehouse Subs and more.","publisher":{"@type":"Organization","name":"Yahoo News","logo":{"@type":"ImageObject","url":"https://s.yimg.com/rz/p/yahoo_news_en-US_h_p_news_2.png","width":310,"height":50},"url":"https://news.yahoo.com/"},"author":{"@type":"Person","name":"Gary T. Mills, Florida Times-Union","jobTitle":""},"creator":{"@type":"Person","name":"Gary T. Mills, Florida Times-Union","jobTitle":""},"provider":{"@type":"Organization","name":"The Florida Times-Union","url":"https://www.jacksonville.com"},"image":{"@type":"ImageObject","width":871,"height":393,"url":"https://s.yimg.com/uu/api/res/1.2/fbCri1EAwxGF6xK7FW5Z0w--~B/aD0zOTM7dz04NzE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/the-florida-times-union/6e2c3649d4e968e8f132feefd3af4934"},"thumbnailUrl":"https://s.yimg.com/uu/api/res/1.2/fbCri1EAwxGF6xK7FW5Z0w--~B/aD0zOTM7dz04NzE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/the-florida-times-union/6e2c3649d4e968e8f132feefd3af4934"}
#           </script>
#           <header class="caas-header">
#            <div class="caas-logo">
#             <a class="link caas-attr-provider" data-ylk="sec:logo-provider;elm:pvdr_name;slk:The Florida Times-Union;g:" href="https://www.jacksonville.com" rel="noopener noreferrer" target="_blank" title="">
#              The Florida Times-Union
#             </a>
#            </div>
#            <header class="caas-title-wrapper">
#             <h1 data-test-locator="headline">
#              Something (really) sweet is headed this way
#             </h1>
#            </header>
#           </header>
#           <script class="caas-yvideo-config" type="application/ld+json">
#            {"videoDockingCfg":{"enableOnMuted":true,"enableOnScrollDown":true,"enableOnScrollUp":false,"fadeInAnimation":true,"height":225,"positionBottom":0,"positionLeft":-1,"positionRight":20,"positionTop":-1,"showInfoCard":false,"width":400,"threshold":10}}
#           </script>
#           <script class="caas-timezone-config" type="application/ld+json">
#            {"longForm":{"weekday":"short","day":"numeric","hour":"numeric","hourCycle":"h12","minute":"2-digit","month":"long","year":"numeric"},"shortForm":{"day":"numeric","month":"long","year":"numeric"}}
#           </script>
#           <script class="caas-embedded-config" type="application/ld+json">
#            {"twitter":{"timeout":5000}}
#           </script>
#           <div class="caas-body-wrapper">
#            <button class="caas-button noborder caas-body-collapse-button" data-ylk="sitc:1;slk:Read full article">
#             Read full article
#             <i>
#             </i>
#            </button>
#            <div class="caas-body-content">
#             <div class="caas-body-inner-wrapper">
#              <div class="caas-body-section">
#               <div>
#                <figure class="caas-figure caas-cover">
#                 <div class="caas-figure-with-pb" style="max-height: 318px">
#                  <div>
#                   <div class="caas-img-container" style="padding-bottom:45%;">
#                    <img alt="" class="caas-img" data-src="https://s.yimg.com/ny/api/res/1.2/nP2Da0cVvyvw_.METQb6xQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTcwNTtoPTMxOA--/https://s.yimg.com/uu/api/res/1.2/fbCri1EAwxGF6xK7FW5Z0w--~B/aD0zOTM7dz04NzE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/the-florida-times-union/6e2c3649d4e968e8f132feefd3af4934" src="https://s.yimg.com/ny/api/res/1.2/nP2Da0cVvyvw_.METQb6xQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTcwNTtoPTMxOA--/https://s.yimg.com/uu/api/res/1.2/fbCri1EAwxGF6xK7FW5Z0w--~B/aD0zOTM7dz04NzE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/the-florida-times-union/6e2c3649d4e968e8f132feefd3af4934"/>
#                   </div>
#                  </div>
#                 </div>
#                </figure>
#               </div>
#               <div class="caas-content wafer wafer-sticky" data-wf-sticky-boundary="caas-body-section" data-wf-sticky-offset="165px   10px" data-wf-sticky-target=".caas-share-buttons">
#                <div class="caas-share-section">
#                 <div class="caas-share-buttons">
#                  <a class="link caas-button noborder caas-tooltip facebook top" data-ylk="t4:ctrl;elm:share;elmt:sh-fb;slk:Facebook;itc:0;outcm:share;rspns:op" href="https://www.facebook.com/dialog/feed?app_id=458584288257241&amp;link=https%3A%2F%2Fnews.yahoo.com%2Fsomething-really-sweet-headed-way-224350769.html%3Fsoc_src%3Dsocial-sh%26soc_trk%3Dfb%26tsrc%3Dfb" rel="noopener noreferrer" target="_blank" title="Share">
#                   <span class="facebook icon">
#                    <svg height="20" viewbox="0 0 32 32" width="20">
#                     <path d="M12.752 30.4V16.888H9.365V12.02h3.387V7.865c0-3.264 2.002-6.264 6.613-6.264 1.866 0 3.248.19 3.248.19l-.11 4.54s-1.404-.013-2.943-.013c-1.66 0-1.93.81-1.93 2.152v3.553h5.008l-.22 4.867h-4.786V30.4h-4.88z" transform="">
#                     </path>
#                    </svg>
#                   </span>
#                  </a>
#                  <a class="link caas-button noborder caas-tooltip twitter top" data-ylk="t4:ctrl;elm:share;elmt:sh-tw;slk:Twitter;itc:0;outcm:share;rspns:op" href="https://twitter.com/intent/tweet?text=Something%20(really)%20sweet%20is%20headed%20this%20way&amp;url=https%3A%2F%2Fnews.yahoo.com%2Fsomething-really-sweet-headed-way-224350769.html%3Fsoc_src%3Dsocial-sh%26soc_trk%3Dtw%26tsrc%3Dtwtr&amp;via=YahooNews" rel="noopener noreferrer" target="_blank" title="Tweet">
#                   <span class="twitter icon">
#                    <svg height="20" viewbox="0 0 32 32" width="20">
#                     <path d="M30.402 7.094c-1.058.47-2.198.782-3.392.928 1.218-.725 2.154-1.885 2.595-3.256-1.134.674-2.405 1.165-3.75 1.43-1.077-1.148-2.612-1.862-4.31-1.862-3.268 0-5.915 2.635-5.915 5.893 0 .464.056.91.155 1.34-4.915-.244-9.266-2.59-12.18-6.158-.51.87-.806 1.885-.806 2.96 0 2.044 1.045 3.847 2.633 4.905-.974-.032-1.883-.3-2.68-.736v.07c0 2.857 2.034 5.236 4.742 5.773-.498.138-1.022.21-1.56.21-.38 0-.75-.034-1.11-.103.75 2.344 2.93 4.042 5.518 4.09-2.024 1.58-4.57 2.523-7.333 2.523-.478 0-.952-.032-1.41-.085 2.613 1.674 5.72 2.65 9.054 2.65 10.872 0 16.814-8.976 16.814-16.765 0-.254-.008-.507-.018-.762 1.155-.83 2.155-1.868 2.95-3.047z" transform="">
#                     </path>
#                    </svg>
#                   </span>
#                  </a>
#                  <a class="link caas-button noborder caas-tooltip mail top" data-ylk="t4:ctrl;elm:share;elmt:sh-ma;slk:Email;itc:0;outcm:share;rspns:op" href="mailto:?subject=Something%20(really)%20sweet%20is%20headed%20this%20way&amp;body=https%3A%2F%2Fnews.yahoo.com%2Fsomething-really-sweet-headed-way-224350769.html%3Fsoc_src%3Dsocial-sh%26soc_trk%3Dma" rel="noopener noreferrer" target="_blank" title="Email">
#                   <span class="mail icon">
#                    <svg height="20" viewbox="0 0 512 512" width="20">
#                     <path d="M460.586 91.31H51.504c-10.738 0-19.46 8.72-19.46 19.477v40.088l224 104.03 224-104.03v-40.088c0-10.757-8.702-19.478-19.458-19.478M32.046 193.426V402.96c0 10.758 8.72 19.48 19.458 19.48h409.082c10.756 0 19.46-8.722 19.46-19.48V193.428l-224 102.327-224-102.327z" transform="">
#                     </path>
#                    </svg>
#                   </span>
#                  </a>
#                 </div>
#                </div>
#                <div class="caas-content-wrapper">
#                 <div>
#                  <div class="caas-attr">
#                   <div class="caas-attr-meta">
#                    <div class="caas-attr-item-author">
#                     <span class="caas-author-byline-collapse">
#                      Gary T. Mills, Florida Times-Union
#                     </span>
#                    </div>
#                    <div class="caas-attr-time-style">
#                     <time class="caas-attr-meta-time" datetime="2021-12-01T14:33:12.000Z">
#                      December 1, 2021, 8:33 AM
#                     </time>
#                     <span class="caas-attr-meta-separator">
#                      ·
#                     </span>
#                     <span>
#                      3 min read
#                     </span>
#                    </div>
#                   </div>
#                  </div>
#                  <div class="caas-content-contain-share">
#                   <div class="caas-attr-separator">
#                    <div class="separator">
#                    </div>
#                    <div class="separator-ext">
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                 <div class="caas-body">
#                  <p>
#                   With Thanksgiving in the rear-view mirror (even with turkey leftovers still in the fridge), we’re starting to look forward to Jacksonville’s dining scene in 2022.
#                  </p>
#                  <p>
#                   Among the new restaurants slated to open next year is
#                   <strong>
#                    <a class="link" data-ylk="slk:Sugar Factory American Brasserie" href="https://www.jacksonville.com/story/entertainment/dining/2021/11/18/sugar-factory-open-jacksonville-markets-town-center-spring-2022/6353059001/" rel="nofollow noopener" target="_blank">
#                     Sugar Factory American Brasserie
#                    </a>
#                   </strong>
#                   at the Markets at Town Center, where diners can (really) treat themselves to $25, celebrity-endorsed Couture Pops and a $99, 24-scoop ice cream sundae. (Really.) But Sugar Factory is more than just heaps and heaps of sugar, the Times-Union's Teresa Stepzinski reports. A spring opening is planned.
#                  </p>
#                  <p>
#                   Nearby at the St. Johns Town Center, work is underway at
#                   <strong>
#                    Fresh Mex &amp; Co.
#                   </strong>
#                   , a fast-casual urban grill and cantina set to take over the former Select Comfort spot between P.F. Chang’s China Bistro and M Shack. The restaurant will be the second location for
#                   <strong>
#                    Amanda and Michael Toussaint’s
#                   </strong>
#                   Tex-Mex cantina concept, which launched in 2017 at 7111 Bonneval Road.
#                  </p>
#                  <div class="caas-da">
#                   <div id="sda-INARTICLE">
#                   </div>
#                  </div>
#                  <p>
#                   Also coming next year is the second of as many as nine
#                   <strong>
#                    Huey Magoo’s
#                   </strong>
#                   locations planned for the greater Jacksonville area. After
#                   <a class="link" data-ylk="slk:opening his first restaurant in mid-October" href="https://www.jacksonville.com/story/entertainment/dining/2021/10/14/huey-magoos-opens-first-chicken-tender-restaurant-jacksonville/6097238001/" rel="nofollow noopener" target="_blank">
#                    opening his first restaurant in mid-October
#                   </a>
#                   at South Beach Regional shopping center in Jacksonville Beach, franchisee
#                   <strong>
#                    Michael Phillips
#                   </strong>
#                   is eyeing the former Bank of America spot at Old St. Augustine and Hartley roads in Mandarin for his next location. Known for its cooked-to-order chicken tenders, Central Florida-based Huey Magoo’s has
#                   <a class="link" data-ylk="slk:plans to add 200 restaurants" href="https://www.jacksonville.com/story/entertainment/dining/2021/06/17/florida-based-huey-magoos-famous-chicken-tenders-city-near-you/7733292002/" rel="nofollow noopener" target="_blank">
#                    plans to add 200 restaurants
#                   </a>
#                   in Florida and eight other states. (Another franchise group is planning a restaurant in St. Augustine at a former Krystal site.)
#                  </p>
#                  <p>
#                   <strong>
#                    See you soon, Singleton's:
#                   </strong>
#                   After more than 50 years,
#                   <strong>
#                    Singleton's Seafood Shack
#                   </strong>
#                   is temporarily closing. A week ago, the restaurant broke the news to diners on Facebook: "It’s with a sad heart that myself and family here at Singleton’s will have to close until we finish our renovations on the restaurant, we are working super hard to get back open fully so you can enjoy what we all here at Singleton’s want and expect you to enjoy." In 1969,
#                   <strong>
#                    Capt. Ray and Ann Singleton
#                   </strong>
#                   first began serving breakfast and lunch to Mayport's shrimpers out of a 20-by-20 building. They added dinner and more dining space. And more diners followed, including celebrity chef
#                   <strong>
#                    Guy Fieri
#                   </strong>
#                   , who stopped by with a production crew in 2010 for an episode of the Food Network's "Diners, Drive-ins and Dives."
#                  </p>
#                  <div class="caas-readmore caas-readmore-collapse">
#                   <button aria-label="" class="link caas-button collapse-button" data-ylk="elm:readmore;slk:Story continues" title="">
#                    Story continues
#                   </button>
#                  </div>
#                  <p>
#                   <strong>
#                    Where’s all the Jewish food in Jacksonville?
#                   </strong>
#                   That's the question Times-Union reporter Emily Bloch
#                   <a class="link" data-ylk="slk:recently asked (and answered)" href="https://www.jacksonville.com/story/lifestyle/food/2021/11/27/jacksonville-jewish-food-restaurants-where-to-find-matzo-balls-challah-more/6392865001/" rel="nofollow noopener" target="_blank">
#                    recently asked (and answered)
#                   </a>
#                   . If you thought the city’s challah supply disappeared with the closing (and subsequent demolition) of
#                   <strong>
#                    Worman’s Bakery
#                   </strong>
#                   in 2009, you’ll be glad to know there are some worthy successors. And to those who celebrate, Happy Hanukkah.
#                  </p>
#                  <p>
#                   <span class="exclude-from-newsgate">
#                    <strong>
#                     More:
#                    </strong>
#                    <a class="link" data-ylk="slk:5 must-try Jewish foods in Jacksonville" href="https://www.jacksonville.com/story/lifestyle/food/2021/11/27/five-jewish-foods-jacksonville-you-have-try/8726701002/" rel="nofollow noopener" target="_blank">
#                     5 must-try Jewish foods in Jacksonville
#                    </a>
#                   </span>
#                  </p>
#                  <p>
#                   <strong>
#                    Attention restaurant owners:
#                   </strong>
#                   If you plan to open on Christmas Day, share your dining plans with us
#                   <a class="link" data-ylk="slk:using this form" href="https://forms.gle/i5KNTWW9PwTWdEba8" rel="nofollow noopener" target="_blank">
#                    using this form
#                   </a>
#                   . For other news, please email gmills@jacksonville.com.
#                  </p>
#                  <p>
#                   And for those who still have turkey leftovers in the fridge, throw them out and head out to your favorite restaurant or find a new one.
#                  </p>
#                  <p>
#                   For more dining news, keep reading using the links below.
#                  </p>
#                  <p>
#                   Cheers!
#                  </p>
#                  <p>
#                   Gary Mills
#                  </p>
#                  <p>
#                   Deputy Managing Editor
#                  </p>
#                  <p>
#                   The Florida Times-Union
#                  </p>
#                  <p>
#                   Email: gmills@jacksonville.com
#                  </p>
#                  <p>
#                   Twitter:
#                   <a class="link" data-ylk="slk:@garytmills" href="https://twitter.com/garytmills/" rel="nofollow noopener" target="_blank">
#                    @garytmills
#                   </a>
#                  </p>
#                  <p>
#                   <em>
#                    This article originally appeared on Florida Times-Union:
#                    <a class="link" data-ylk="slk:Something (really) sweet is headed this way" href="https://www.jacksonville.com/story/nletter/dining-notes/2021/11/30/something-really-sweet-headed-way/8800878002/" rel="nofollow noopener" target="_blank">
#                     Something (really) sweet is headed this way
#                    </a>
#                   </em>
#                  </p>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </article>
#         </div>
#        </div>
#        <script type="text/javascript">
#         (function(w) {
#         var adsConfig = {
#             clientPositionMeta: undefined,
#             clientViewportAdFetchYOffset: undefined,
#             clusterPositionMeta: undefined,
#             enableAdditionalPageContextParams: undefined,
#             pencilAdSections: {},
#             positions: {"BTNA":{"meta":{"clean":"sda-BTN","dest":"sda-BTN-iframe","fdb":1,"h":60,"id":"BTNA","metaSize":true,"w":120},"sfoptin":1},"BTNB":{"meta":{"clean":"sda-BTN-1","dest":"sda-BTN-1-iframe","fdb":1,"h":60,"id":"BTNB","metaSize":true,"w":120},"sfoptin":1},"BTNC":{"meta":{"clean":"sda-BTN-2","dest":"sda-BTN-2-iframe","fdb":1,"h":60,"id":"BTNC","metaSize":true,"w":120},"sfoptin":1},"BTND":{"meta":{"clean":"sda-BTN-3","dest":"sda-BTN-3-iframe","fdb":1,"h":60,"id":"BTND","metaSize":true,"w":120},"sfoptin":1},"FSRVY":{"meta":{"clean":"sda-FSRVY","dest":"sda-FSRVY-iframe","fr":"expIfr_exp","id":"FSRVY","supports":{"lyr":1}}},"HPSPON":{"filtered":1,"sfoptin":0},"INARTICLE":{"meta":{"clean":"sda-INARTICLE-base","dest":"sda-INARTICLE","fdb":1,"flex":{"h":{"min":10},"ratio":"1.78x1","w":{"min":10}},"h":211,"id":"INARTICLE","pos":"LREC","supports":{"exp-ovr":1,"exp-push":1,"lyr":0},"w":375},"sfoptin":1},"INBODYLDRB-DISPLAY-PH":{"meta":{"clean":"sda-placeholder","dest":"sda-placeholder-iframe","fdb":1,"h":90,"id":"LDRB","metaSize":true,"pos":"LDRB","supports":{"exp-ovr":1,"exp-push":1,"lyr":0},"w":728}},"INBODYLDRB-NATIVE-PH":{"meta":{"clean":"sda-placeholder","dest":"sda-placeholder-iframe","fdb":1,"h":90,"id":"LDRB","metaSize":true,"pos":"LDRB","supports":{"exp-ovr":1,"exp-push":1,"lyr":0},"w":728,"doubleBuffering":false}},"INBODYLDRB2-DISPLAY-PH":{"meta":{"clean":"sda-placeholder","dest":"sda-placeholder-iframe","fdb":1,"h":90,"id":"LDRB","metaSize":true,"pos":"LDRB","supports":{"exp-ovr":1,"exp-push":1,"lyr":0},"w":728}},"INBODYLDRB2-NATIVE-PH":{"meta":{"clean":"sda-placeholder","dest":"sda-placeholder-iframe","fdb":1,"h":90,"id":"LDRB","metaSize":true,"pos":"LDRB","supports":{"exp-ovr":1,"exp-push":1,"lyr":0},"w":728,"doubleBuffering":false}},"INBODYLDRB3-DISPLAY-PH":{"meta":{"clean":"sda-placeholder","dest":"sda-placeholder-iframe","fdb":1,"h":90,"id":"LDRB","metaSize":true,"pos":"LDRB","supports":{"exp-ovr":1,"exp-push":1,"lyr":0},"w":728}},"INBODYLDRB3-NATIVE-PH":{"meta":{"clean":"sda-placeholder","dest":"sda-placeholder-iframe","fdb":1,"h":90,"id":"LDRB","metaSize":true,"pos":"LDRB","supports":{"exp-ovr":1,"exp-push":1,"lyr":0},"w":728,"doubleBuffering":false}},"INBODYLDRB4-DISPLAY-PH":{"meta":{"clean":"sda-placeholder","dest":"sda-placeholder-iframe","fdb":1,"h":90,"id":"LDRB","metaSize":true,"pos":"LDRB","supports":{"exp-ovr":1,"exp-push":1,"lyr":0},"w":728}},"INBODYLDRB4-NATIVE-PH":{"meta":{"clean":"sda-placeholder","dest":"sda-placeholder-iframe","fdb":1,"h":90,"id":"LDRB","metaSize":true,"pos":"LDRB","supports":{"exp-ovr":1,"exp-push":1,"lyr":0},"w":728,"doubleBuffering":false}},"INBODYLREC-DISPLAY-PH":{"meta":{"clean":"sda-placeholder","dest":"sda-placeholder-iframe","fdb":1,"h":250,"id":"LREC","metaSize":true,"pos":"LREC","supports":{"exp-ovr":0,"exp-push":1,"lyr":0},"w":300}},"INBODYLREC-NATIVE-PH":{"meta":{"clean":"sda-placeholder","dest":"sda-placeholder-iframe","fdb":1,"h":250,"id":"LREC","metaSize":true,"pos":"LREC","supports":{"exp-ovr":0,"exp-push":1,"lyr":0},"w":300,"doubleBuffering":false,"flex":{"w":{"max":375}}}},"INBODYLREC2-DISPLAY-PH":{"meta":{"clean":"sda-placeholder","dest":"sda-placeholder-iframe","fdb":1,"h":250,"id":"LREC","metaSize":true,"pos":"LREC","supports":{"exp-ovr":0,"exp-push":1,"lyr":0},"w":300}},"INBODYLREC2-NATIVE-PH":{"meta":{"clean":"sda-placeholder","dest":"sda-placeholder-iframe","fdb":1,"h":250,"id":"LREC","metaSize":true,"pos":"LREC","supports":{"exp-ovr":0,"exp-push":1,"lyr":0},"w":300,"doubleBuffering":false,"flex":{"w":{"max":375}}}},"INBODYLREC3-DISPLAY-PH":{"meta":{"clean":"sda-placeholder","dest":"sda-placeholder-iframe","fdb":1,"h":250,"id":"LREC","metaSize":true,"pos":"LREC","supports":{"exp-ovr":0,"exp-push":1,"lyr":0},"w":300}},"INBODYLREC3-NATIVE-PH":{"meta":{"clean":"sda-placeholder","dest":"sda-placeholder-iframe","fdb":1,"h":250,"id":"LREC","metaSize":true,"pos":"LREC","supports":{"exp-ovr":0,"exp-push":1,"lyr":0},"w":300,"doubleBuffering":false,"flex":{" ...
#             rotateIndexPageAds: undefined,
#             rotation: {},
#             strings: {"advertisement":"Advertisement"},
#             videoPublisherBlob: "lu:0;lpstaid:6249b3e3-97ad-3c63-830a-39f9327800a2;pt:content;ver:article;pd:non_modal;pct:story",
#             viewerEnableLRECForShowBodyAdsFalse: undefined,
#             viewerGeminiSMAdConfig: {},
#             viewerGeminiSMAdEnabled: undefined,
#             viewerPositionMeta: undefined,
#             viewerResetAutoEventOnClose: undefined,
#             viewerSMAdEnabled: undefined,
#             viewerViewportAdFetch: {},
#             viewerWfpadAdEnabled: undefined,
#             viewerWfpadInVideoEnabled: undefined,
#         };
#
#         // expose adsConfig for homepage-viewer client
#         if (!w.adsConfig) {
#             w.adsConfig = adsConfig;
#         }
#     }(window));
#        </script>
#        <script id="wafer-caas-config" type="application/json">
#         {
#         "caasUrl": "https://www.yahoo.com/caas/content/article/",
#         "contextParams": "lang=en-US&region=US&site=news"
#     }
#        </script>
#       </div>
#      </div>
#     </div>
#     <div class="Pos(r) Pstart(12%) Pend(10%) Mb($gridMargin) Mt(-20px)" id="postArticle">
#     </div>
#     <div class="wafer-rapid-module Pos(r) Mb(40px)" id="module-spotIm">
#      <section id="spot-im-comments">
#       <style>
#        body.ow-modal-opened #spotIm-conversations-module-wrapper iframe {
#         z-index: 11 !important;
#     }
#       </style>
#       <script class="wafer-state" type="application/json">
#        {"spotIm":{"conversationEnabled":false,"device":"desktop","jacDomain":"https://openweb.jac.yahoosandbox.com","jacUrl":"https://openweb.jac.yahoosandbox.com/0.8.1/jac.js","launcherUrl":"https://launcher.spot.im/spot/","leftRailWidth":"","messages_cnt":0,"passiveReactionEnabled":false,"pitcAdEnabled":true,"pitcEnabled":true,"showCommentCount":false,"spotId":"sp_Rba9aFpG","stageSpotId":"sp_n93tLsKu","url":"https://news.yahoo.com/something-really-sweet-headed-way-224350769.html","useCase":"deeplink","useStageToken":false,"uuid":"6249b3e3-97ad-3c63-830a-39f9327800a2","xhrPathPrefix":"/nel_ms/_rcv/remote"}}
#       </script>
#       <div class="C(#828c93) Lh(20px) Fz(14px) Fw(500) BdT Bdtc(#222) Bdtw(2px) Mt(20px) Pt(24px) Py(24px)">
#        Our goal is to create a safe and engaging place for users to connect over interests and passions. In order to improve our community experience, we are temporarily suspending article commenting
#       </div>
#       <div id="spotIm-conversations-module-wrapper">
#       </div>
#      </section>
#      <script>
#       window.performance.mark('spotIm');
#                     window.performance.measure('spotImDone','PageStart','spotIm');
#      </script>
#     </div>
#     <div class="Ta(c) Mb($articleAdMargin) LDRB2-status-error" id="sda-LDRB2">
#      <div id="sda-LDRB2-iframe">
#       <noscript>
#        <!-- SpaceID=0 robot -->
#       </noscript>
#      </div>
#     </div>
#     <div class="wafer-rapid-module Mb(24px)" id="module-moreStories">
#      <div class="stream" data-wf-sticky-offset="130px   10px" data-wf-sticky-target="#adsStream" data-wf-trigger-percentage="" id="stream-wrapper">
#       <div class="header-wrapper D(b) Bds(s) Bdc(headerWrapperTopBorderColor) Bdw(headerTitleSolidTopBorderWidth)">
#        <h2 class="header M(0) Fw(900) C(#1e1e1e) Cur(d) Fz(24px) Fw(900) Mb(15px) Pt(10px) W($gridMaxWidth) Cnt(emptyContent)::b D(ib)::b Va(m)::b W(38px)::b H(36px)::b Bg(headerTitleBGColor)::b Mend(16px)::b">
#         <div class="D(ib) Td(n) C($c-fuji-grey-m)">
#          Recommended Stories
#         </div>
#        </h2>
#       </div>
#       <ul class="common simple-list Pstart(0)">
#        <li class="common simple-list-item stream-item D(n):e stream-list Mt(20px) Mt(0):fc Mb(25px) Mih(144px) js-stream-content">
#         <div class="item-hover-trigger Pos(r)">
#          <div class="item-img-wrapper Pos(r) Fl(start) Mend(16px) Ov(h) Fxs(0) Bdrs(8px) Z(0)">
#           <img alt="" class="Mah(168px) W(257px) H(144px) D(b) item-hover-trigger:h_Scale(1.05) Trs(listItemTransformTransition) wafer-img" data-wf-src="https://s.yimg.com/uu/api/res/1.2/tAba5saJlrw.7p5VJs9gpQ--~B/Zmk9c3RyaW07aD0yODg7dz01MTQ7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/0iIPhyphdZC0rtA0UQ2bOg--~B/aD0yNzM2O3c9MzY0ODthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/usa_today_news_641/a2df527c657413f28af2ba98a5f9c2d8" src="https://s.yimg.com/cv/apiv2/default/20190501/placeholder.gif"/>
#          </div>
#          <div class="simple-item-content Mih(124px)">
#           <div class="provider-logo C(#000) My(7px) Fw(600) H(18px)">
#            <span class="D(ib) Mt(2px) Mb(4px) C($c-fuji-grey-m)">
#             USA TODAY
#            </span>
#           </div>
#           <h4 class="C($c-fuji-grey-m) Fw(600) Fz(16px) M(0) Mb(5px) Lh(1.25em) Trs(colorTransition) item-hover-trigger:h_C($titleHoverColor)">
#            <a class="Td(n) C($inherit) LineClamp(2,45px) D(f) js-content-viewer rapidnofollow" data-hosted-type="HOSTED" data-uuid="68a20f1b-92b9-3e01-b449-3473487cc8fa" data-wf-caas-prefetch="1" data-wf-caas-uuid="68a20f1b-92b9-3e01-b449-3473487cc8fa" data-ylk="elm:hdln;itc:0;pos:1;sec:strm;subsec:moreforyou;cpos:1;ct:story;g:68a20f1b-92b9-3e01-b449-3473487cc8fa" href="https://news.yahoo.com/teen-ate-leftover-rice-noodles-155422253.html">
#             A teen ate leftover rice and noodles. Hours later, doctors amputated his legs and fingers
#             <div class="StretchedBox Z(1)">
#             </div>
#            </a>
#           </h4>
#           <p class="M(0) C($summaryColor) Fz(14px) Lh(1.43em) LineClamp(3,60px)">
#            Just hours after eating leftover rice, chicken and lo mein from a restaurant, a Massachusetts student was in the hospital with meningococcal disease.
#           </p>
#          </div>
#         </div>
#         <div class="action-bar D(f) Fld(r) Fxw(w) Jc(left) Ai(fs) Lh(1.43em) Mt(3px)">
#          <div class="Fz(12px) C($commentColor)">
#           <span class="duration">
#            <label>
#             58m ago
#            </label>
#           </span>
#          </div>
#          <div class="actions">
#          </div>
#         </div>
#        </li>
#        <li class="common simple-list-item stream-item D(n):e stream-list Mt(20px) Mt(0):fc Mb(25px) Mih(144px) js-stream-content">
#         <div class="item-hover-trigger Pos(r)">
#          <div class="item-img-wrapper Pos(r) Fl(start) Mend(16px) Ov(h) Fxs(0) Bdrs(8px) Z(0)">
#           <img alt="" class="Mah(168px) W(257px) H(144px) D(b) item-hover-trigger:h_Scale(1.05) Trs(listItemTransformTransition) wafer-img" data-wf-src="https://s.yimg.com/uu/api/res/1.2/.qrsMY_7qvhug7GwCbfT.A--~B/Zmk9c3RyaW07aD0yODg7dz01MTQ7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/lyVqisldr9B8R.ZavIFLxQ--~B/aD00ODU7dz03Mjg7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/reuters.com/407cf98c63937ad89601c22ed205f1a0" src="https://s.yimg.com/cv/apiv2/default/20190501/placeholder.gif"/>
#          </div>
#          <div class="simple-item-content Mih(124px)">
#           <div class="provider-logo C(#000) My(7px) Fw(600) H(18px)">
#            <span class="D(ib) Mt(2px) Mb(4px) C($c-fuji-grey-m)">
#             Reuters
#            </span>
#           </div>
#           <h4 class="C($c-fuji-grey-m) Fw(600) Fz(16px) M(0) Mb(5px) Lh(1.25em) Trs(colorTransition) item-hover-trigger:h_C($titleHoverColor)">
#            <a class="Td(n) C($inherit) LineClamp(2,45px) D(f) js-content-viewer rapidnofollow" data-hosted-type="HOSTED" data-uuid="358a27ad-ec47-38dd-98b0-bb500a4ddc11" data-wf-caas-prefetch="1" data-wf-caas-uuid="358a27ad-ec47-38dd-98b0-bb500a4ddc11" data-ylk="elm:hdln;itc:0;pos:1;sec:strm;subsec:moreforyou;cpos:2;ct:story;g:358a27ad-ec47-38dd-98b0-bb500a4ddc11" href="https://news.yahoo.com/u-supreme-court-formally-ends-145516807.html">
#             U.S. Supreme Court formally ends Trump's fight over Capitol attack records
#             <div class="StretchedBox Z(1)">
#             </div>
#            </a>
#           </h4>
#           <p class="M(0) C($summaryColor) Fz(14px) Lh(1.43em) LineClamp(3,60px)">
#            The U.S. Supreme Court on Tuesday brought a formal end to former President Donald Trump's request to block the release of White House records sought by the Democratic-led congressional panel investigating last year's deadly attack on the Capitol by a mob of his supporters.  The court's decision to formally reject Trump's appeal follows its Jan. 19 order that led to the documents being handed over to the House of Representatives investigative committee by the federal agency that stores government and historical records.  The U.S. Court of Appeals for the District of Columbia Circuit on Dec. 9 upheld a lower court ruling that Trump had no basis to challenge President Joe Biden's decision to allow the records to be handed over to the House of Representatives select committee.
#           </p>
#          </div>
#         </div>
#         <div class="action-bar D(f) Fld(r) Fxw(w) Jc(left) Ai(fs) Lh(1.43em) Mt(3px)">
#          <div class="Fz(12px) C($commentColor)">
#           <span class="duration">
#            <label>
#             4h ago
#            </label>
#           </span>
#          </div>
#          <div class="actions">
#          </div>
#         </div>
#        </li>
#        <li class="common simple-list-item stream-item D(n):e stream-list Mt(20px) Mt(0):fc Mb(25px) Mih(144px) js-stream-content">
#         <div class="item-hover-trigger Pos(r)">
#          <div class="item-img-wrapper Pos(r) Fl(start) Mend(16px) Ov(h) Fxs(0) Bdrs(8px) Z(0)">
#           <img alt="" class="Mah(168px) W(257px) H(144px) D(b) item-hover-trigger:h_Scale(1.05) Trs(listItemTransformTransition) wafer-img" data-wf-src="https://s.yimg.com/uu/api/res/1.2/H5E.LBCMUuCfnSoFur3vRg--~B/Zmk9c3RyaW07aD0yODg7dz01MTQ7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/vpQ2pN9BgWNvCst557n35A--~B/aD05NTA7dz0xMjY3O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/business_insider_articles_888/983dddabbd97adc9784d82cb3736e468" src="https://s.yimg.com/cv/apiv2/default/20190501/placeholder.gif"/>
#          </div>
#          <div class="simple-item-content Mih(124px)">
#           <div class="provider-logo C(#000) My(7px) Fw(600) H(18px)">
#            <span class="D(ib) Mt(2px) Mb(4px) C($c-fuji-grey-m)">
#             Business Insider
#            </span>
#           </div>
#           <h4 class="C($c-fuji-grey-m) Fw(600) Fz(16px) M(0) Mb(5px) Lh(1.25em) Trs(colorTransition) item-hover-trigger:h_C($titleHoverColor)">
#            <a class="Td(n) C($inherit) LineClamp(2,45px) D(f) js-content-viewer rapidnofollow" data-hosted-type="HOSTED" data-uuid="0bd78085-d95c-3d61-ab87-3a127ede62ee" data-wf-caas-prefetch="1" data-wf-caas-uuid="0bd78085-d95c-3d61-ab87-3a127ede62ee" data-ylk="elm:hdln;itc:0;pos:1;sec:strm;subsec:moreforyou;cpos:3;ct:story;g:0bd78085-d95c-3d61-ab87-3a127ede62ee" href="https://news.yahoo.com/kremlin-admits-dramatic-security-council-123452192.html">
#             Kremlin admits that a dramatic Security Council meeting on Ukraine was recorded in advance, after people realized a minister's watch showed the wrong time
#             <div class="StretchedBox Z(1)">
#             </div>
#            </a>
#           </h4>
#           <p class="M(0) C($summaryColor) Fz(14px) Lh(1.43em) LineClamp(3,60px)">
#            Kremlin Press Secretary Dmitry Peskov said Tuesday that recording meetings in advance is not unusual.
#           </p>
#          </div>
#         </div>
#         <div class="action-bar D(f) Fld(r) Fxw(w) Jc(left) Ai(fs) Lh(1.43em) Mt(3px)">
#          <div class="Fz(12px) C($commentColor)">
#           <span class="duration">
#            <label>
#             6h ago
#            </label>
#           </span>
#          </div>
#          <div class="actions">
#          </div>
#         </div>
#        </li>
#        <li class="common simple-list-item stream-item D(n):e stream-list Mt(20px) Mt(0):fc Mb(25px) Mih(144px) js-stream-content">
#         <div class="item-hover-trigger Pos(r)">
#          <div class="item-img-wrapper Pos(r) Fl(start) Mend(16px) Ov(h) Fxs(0) Bdrs(8px) Z(0)">
#           <img alt="" class="Mah(168px) W(257px) H(144px) D(b) item-hover-trigger:h_Scale(1.05) Trs(listItemTransformTransition) wafer-img" data-wf-src="https://s.yimg.com/uu/api/res/1.2/acfYfd5.oArbXqAPCmSQnw--~B/Zmk9c3RyaW07aD0yODg7dz01MTQ7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/goSITzjX9.7IfCblRUPqMg--~B/aD0xMDgwO3c9MTkyMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/thestreet.com/b106d2dae4d5c0aa2f9dfb6de17cd170" src="https://s.yimg.com/cv/apiv2/default/20190501/placeholder.gif"/>
#          </div>
#          <div class="simple-item-content Mih(124px)">
#           <div class="provider-logo C(#000) My(7px) Fw(600) H(18px)">
#            <span class="D(ib) Mt(2px) Mb(4px) C($c-fuji-grey-m)">
#             TheStreet.com
#            </span>
#           </div>
#           <h4 class="C($c-fuji-grey-m) Fw(600) Fz(16px) M(0) Mb(5px) Lh(1.25em) Trs(colorTransition) item-hover-trigger:h_C($titleHoverColor)">
#            <a class="Td(n) C($inherit) LineClamp(2,45px) D(f) js-content-viewer rapidnofollow" data-hosted-type="HOSTED" data-uuid="7915a27a-4511-36ba-846b-c648b940c473" data-wf-caas-prefetch="1" data-wf-caas-uuid="7915a27a-4511-36ba-846b-c648b940c473" data-ylk="elm:hdln;itc:0;pos:1;sec:strm;subsec:moreforyou;cpos:4;ct:story;g:7915a27a-4511-36ba-846b-c648b940c473" href="https://www.yahoo.com/news/m/7915a27a-4511-36ba-846b-c648b940c473/las-vegas-may-add-another.html">
#             Las Vegas May Add Another Huge Sports Franchise
#             <div class="StretchedBox Z(1)">
#             </div>
#            </a>
#           </h4>
#           <p class="M(0) C($summaryColor) Fz(14px) Lh(1.43em) LineClamp(3,60px)">
#            Negotiations are underway on something big that could be a major driver for strip leaders Caesars and MGM.
#           </p>
#          </div>
#         </div>
#         <div class="action-bar D(f) Fld(r) Fxw(w) Jc(left) Ai(fs) Lh(1.43em) Mt(3px)">
#          <div class="Fz(12px) C($commentColor)">
#           <span class="duration">
#            <label>
#             55m ago
#            </label>
#           </span>
#          </div>
#          <div class="actions">
#          </div>
#         </div>
#        </li>
#        <li class="common simple-list-item stream-item D(n):e stream-list Mt(20px) Mt(0):fc Mb(25px) Mih(144px) js-stream-content">
#         <div class="item-hover-trigger Pos(r)">
#          <div class="item-img-wrapper Pos(r) Fl(start) Mend(16px) Ov(h) Fxs(0) Bdrs(8px) Z(0)">
#           <img alt="" class="Mah(168px) W(257px) H(144px) D(b) item-hover-trigger:h_Scale(1.05) Trs(listItemTransformTransition) wafer-img" data-wf-src="https://s.yimg.com/uu/api/res/1.2/eFc2ESfeL2TClyl0kLNLeA--~B/Zmk9c3RyaW07aD0yODg7dz01MTQ7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/_Y7USMeTcPYpt4Y9xsT9.A--~B/aD03NjA7dz0xMTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/kansas_city_star_mcclatchy_articles_677/5b25e9c40fe3dcd74b2d1fac91996677" src="https://s.yimg.com/cv/apiv2/default/20190501/placeholder.gif"/>
#          </div>
#          <div class="simple-item-content Mih(124px)">
#           <div class="provider-logo C(#000) My(7px) Fw(600) H(18px)">
#            <span class="D(ib) Mt(2px) Mb(4px) C($c-fuji-grey-m)">
#             Kansas City Star
#            </span>
#           </div>
#           <h4 class="C($c-fuji-grey-m) Fw(600) Fz(16px) M(0) Mb(5px) Lh(1.25em) Trs(colorTransition) item-hover-trigger:h_C($titleHoverColor)">
#            <a class="Td(n) C($inherit) LineClamp(2,45px) D(f) js-content-viewer rapidnofollow" data-hosted-type="HOSTED" data-uuid="e24908d7-4214-3924-952b-fa294682061e" data-wf-caas-prefetch="1" data-wf-caas-uuid="e24908d7-4214-3924-952b-fa294682061e" data-ylk="elm:hdln;itc:0;pos:1;sec:strm;subsec:moreforyou;cpos:5;ct:story;g:e24908d7-4214-3924-952b-fa294682061e" href="https://news.yahoo.com/only-one-former-secretary-state-160444530.html">
#             Only one former secretary of state is praising Putin and criticizing Biden in Ukraine crisis
#             <div class="StretchedBox Z(1)">
#             </div>
#            </a>
#           </h4>
#           <p class="M(0) C($summaryColor) Fz(14px) Lh(1.43em) LineClamp(3,60px)">
#            During a moment of peril in Europe, Pompeo is taking to cable news and social media to praise Russian President Vladimir Putin and chastise the Biden administration.
#           </p>
#          </div>
#         </div>
#         <div class="action-bar D(f) Fld(r) Fxw(w) Jc(left) Ai(fs) Lh(1.43em) Mt(3px)">
#          <div class="Fz(12px) C($commentColor)">
#           <span class="duration">
#            <label>
#             3h ago
#            </label>
#           </span>
#          </div>
#          <div class="actions">
#          </div>
#         </div>
#        </li>
#        <li class="common simple-list-item stream-item D(n):e stream-list Mt(20px) Mt(0):fc Mb(25px) Mih(144px) js-stream-content">
#         <div class="item-hover-trigger Pos(r)">
#          <div class="item-img-wrapper Pos(r) Fl(start) Mend(16px) Ov(h) Fxs(0) Bdrs(8px) Z(0)">
#           <img alt="" class="Mah(168px) W(257px) H(144px) D(b) item-hover-trigger:h_Scale(1.05) Trs(listItemTransformTransition) wafer-img" data-wf-src="https://s.yimg.com/uu/api/res/1.2/Me8GWfHxYNkWaTszHzikxA--~B/Zmk9c3RyaW07aD0yODg7dz01MTQ7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/xsPhAob221vCJ9U6on7kTw--~B/aD0xNzA3O3c9MjU2MDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/cincinnati_bengals_wire_usa_today_sports_articles_393/2fffb9a60194ed8ef18c222217657f3a" src="https://s.yimg.com/cv/apiv2/default/20190501/placeholder.gif"/>
#          </div>
#          <div class="simple-item-content Mih(124px)">
#           <div class="provider-logo C(#000) My(7px) Fw(600) H(18px)">
#            <span class="D(ib) Mt(2px) Mb(4px) C($c-fuji-grey-m)">
#             Bengals Wire
#            </span>
#           </div>
#           <h4 class="C($c-fuji-grey-m) Fw(600) Fz(16px) M(0) Mb(5px) Lh(1.25em) Trs(colorTransition) item-hover-trigger:h_C($titleHoverColor)">
#            <a class="Td(n) C($inherit) LineClamp(2,45px) D(f) js-content-viewer rapidnofollow" data-hosted-type="HOSTED" data-uuid="26221634-3c65-3075-9031-ae0bc10a5919" data-wf-caas-prefetch="1" data-wf-caas-uuid="26221634-3c65-3075-9031-ae0bc10a5919" data-ylk="elm:hdln;itc:0;pos:1;sec:strm;subsec:moreforyou;cpos:6;ct:story;g:26221634-3c65-3075-9031-ae0bc10a5919" href="https://news.yahoo.com/aaron-donald-says-joe-burrow-143559114.html">
#             Aaron Donald says Joe Burrow’s comments woke him up during Super Bowl LVI
#             <div class="StretchedBox Z(1)">
#             </div>
#            </a>
#           </h4>
#           <p class="M(0) C($summaryColor) Fz(14px) Lh(1.43em) LineClamp(3,60px)">
#            Some details on what was said on the field during the Super Bowl.
#           </p>
#          </div>
#         </div>
#         <div class="action-bar D(f) Fld(r) Fxw(w) Jc(left) Ai(fs) Lh(1.43em) Mt(3px)">
#          <div class="Fz(12px) C($commentColor)">
#           <span class="duration">
#            <label>
#             4h ago
#            </label>
#           </span>
#          </div>
#          <div class="actions">
#          </div>
#         </div>
#        </li>
#        <li class="common simple-list-item stream-item D(n):e stream-list Mt(20px) Mt(0):fc Mb(25px) Mih(144px) js-stream-content">
#         <div class="item-hover-trigger Pos(r)">
#          <div class="item-img-wrapper Pos(r) Fl(start) Mend(16px) Ov(h) Fxs(0) Bdrs(8px) Z(0)">
# ...
#              <a class="Td(n) C($inherit) LineClamp(3,80px) Mt(12px) js-content-viewer rapidnofollow" data-hosted-type="HOSTED" data-uuid="5701d1b6-a4ce-335c-984b-5aa66f2a27f6" data-wf-caas-prefetch="1" data-wf-caas-uuid="5701d1b6-a4ce-335c-984b-5aa66f2a27f6" data-ylk="sec:rr-stories;elm:hdln;pos:1;itc:0;cpos:8;ct:video;g:5701d1b6-a4ce-335c-984b-5aa66f2a27f6" href="https://news.yahoo.com/woman-accused-fatally-stabbing-husband-232805809.html">
#               Woman accused of fatally stabbing husband more than 140 times
#               <div class="StretchedBox Z(1)">
#               </div>
#              </a>
#             </h4>
#             <div class="provider-logo C($providerColor) Mt(4px) Fw(500) Fz(11px)">
#              <span class="D(ib) Mt(2px) Mb(4px)">
#               WPTV- West Palm Beach Scripps
#              </span>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li class="common simple-list-item-v2 stream-item D(n):e W(100%) Px(10px) Mb(30px) Bxz(bb) Fl(start) js-stream-content">
#           <div class="item-hover-trigger Pos(r)">
#            <div class="item-img-wrapper Pos(r) Ov(h) Fxs(0) Z(0) Bdrs(8px)">
#             <img alt="" class="D(b) W(100%) Mend(10px) Mah(168px) item-hover-trigger:h_Scale(1.05) Trs(listItemTransformTransition) wafer-img" data-wf-src="https://s.yimg.com/uu/api/res/1.2/v_NtVrSEie4mlkX8hPpYlw--~B/Zmk9c3RyaW07aD02MjQ7cT04MDt3PTEyMDA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/hd/cp-video-transcode/production/dd3a9f7e-454c-3095-879b-577eb15140c0/2022-02-20/20-30-54/dee7c2f8-5476-5241-acca-4b91581aa1ff/stream_1280x720x0_v2_3_0.jpg" src="https://s.yimg.com/cv/apiv2/default/20190501/placeholder.gif"/>
#             <span class="Pos(a) Start(50%) T(50%) Translate(translate50PerNeg) Bgi(simpleListItemPlayIconBgGradient) Bxsh(simpleListItemPlayIconBoxShadow) W(60px) H(60px) Bdrs(50%) D(f) Jc(c) Ai(c)">
#              <svg class="Fil(simpleListItemPlayIconFilter) Mstart(2px) Cur(p)" data-icon="CorePlay" height="26" style="fill:#fff;stroke:#fff;stroke-width:0;vertical-align:bottom" viewbox="0 0 512 512" width="24">
#               <path d="M82.294 490.295c-20.327 11.736-36.952 2.14-36.952-21.332V42.295c0-23.472 16.632-33.055 36.952-21.332L451.67 234.295c20.318 11.75 20.318 30.945 0 42.682L82.294 490.295z">
#               </path>
#              </svg>
#             </span>
#            </div>
#            <div class="simple-item-content">
#             <h4 class="C($titleColor) Fw(700) Fz(14px) M(0) Lh(1.71) Trs(colorTransition) item-hover-trigger:h_C($titleHoverColor)">
#              <a class="Td(n) C($inherit) LineClamp(3,80px) Mt(12px) js-content-viewer rapidnofollow" data-hosted-type="HOSTED" data-uuid="dd3a9f7e-454c-3095-879b-577eb15140c0" data-wf-caas-prefetch="1" data-wf-caas-uuid="dd3a9f7e-454c-3095-879b-577eb15140c0" data-ylk="sec:rr-stories;elm:hdln;pos:1;itc:0;cpos:9;ct:video;g:dd3a9f7e-454c-3095-879b-577eb15140c0" href="https://news.yahoo.com/locations-presented-butte-silver-bow-201713208.html">
#               Locations presented for Butte-Silver Bow permanent supportive housing project
#               <div class="StretchedBox Z(1)">
#               </div>
#              </a>
#             </h4>
#             <div class="provider-logo C($providerColor) Mt(4px) Fw(500) Fz(11px)">
#              <span class="D(ib) Mt(2px) Mb(4px)">
#               KPAX
#              </span>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li class="common simple-list-item-v2 stream-item D(n):e W(100%) Px(10px) Mb(30px) Bxz(bb) Fl(start) js-stream-content">
#           <div class="item-hover-trigger Pos(r)">
#            <div class="item-img-wrapper Pos(r) Ov(h) Fxs(0) Z(0) Bdrs(8px)">
#             <img alt="" class="D(b) W(100%) Mend(10px) Mah(168px) item-hover-trigger:h_Scale(1.05) Trs(listItemTransformTransition) wafer-img" data-wf-src="https://s.yimg.com/uu/api/res/1.2/BOLW40.Dt08kY0DilyIhhw--~B/Zmk9c3RyaW07aD02MjQ7cT04MDt3PTEyMDA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/uu/api/res/1.2/4pRpjzVrc9KgSd78jyeVQg--~B/aD0zMDI0O3c9NDAzMjthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/bucks-county-courier-times/d3e8275295f8c53c3cf4a2427cd9e61d" src="https://s.yimg.com/cv/apiv2/default/20190501/placeholder.gif"/>
#            </div>
#            <div class="simple-item-content">
#             <h4 class="C($titleColor) Fw(700) Fz(14px) M(0) Lh(1.71) Trs(colorTransition) item-hover-trigger:h_C($titleHoverColor)">
#              <a class="Td(n) C($inherit) LineClamp(3,80px) Mt(12px) js-content-viewer rapidnofollow" data-hosted-type="HOSTED" data-uuid="0d2e3b5c-532b-304b-a616-00dbe1771bb2" data-wf-caas-prefetch="1" data-wf-caas-uuid="0d2e3b5c-532b-304b-a616-00dbe1771bb2" data-ylk="sec:rr-stories;elm:hdln;pos:1;itc:0;cpos:10;ct:story;g:0d2e3b5c-532b-304b-a616-00dbe1771bb2" href="https://news.yahoo.com/one-bucks-countys-newest-corrections-030020013.html">
#               One of Bucks County's newest corrections officers has four legs and a sensitive snout
#               <div class="StretchedBox Z(1)">
#               </div>
#              </a>
#             </h4>
#             <div class="provider-logo C($providerColor) Mt(4px) Fw(500) Fz(11px)">
#              <span class="D(ib) Mt(2px) Mb(4px)">
#               Bucks County Courier Times
#              </span>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li class="common simple-list-item-v2 stream-item D(n):e W(100%) Px(10px) Mb(30px) Bxz(bb) Fl(start) js-stream-content">
#           <div class="item-hover-trigger Pos(r)">
#            <div class="item-img-wrapper Pos(r) Ov(h) Fxs(0) Z(0) Bdrs(8px)">
#             <img alt="" class="D(b) W(100%) Mend(10px) Mah(168px) item-hover-trigger:h_Scale(1.05) Trs(listItemTransformTransition) wafer-img" data-wf-src="https://s.yimg.com/uu/api/res/1.2/RXuXhNrgIRnIkFSP6F3fBQ--~B/Zmk9c3RyaW07aD02MjQ7cT04MDt3PTEyMDA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/hd/cp-video-transcode/production/f88505e8-e3a5-354f-9f73-ed29fab87448/2022-02-21/00-28-06/d67c1fce-0593-5f63-a553-0921d7b84535/stream_1280x720x0_v2_3_0.jpg" src="https://s.yimg.com/cv/apiv2/default/20190501/placeholder.gif"/>
#             <span class="Pos(a) Start(50%) T(50%) Translate(translate50PerNeg) Bgi(simpleListItemPlayIconBgGradient) Bxsh(simpleListItemPlayIconBoxShadow) W(60px) H(60px) Bdrs(50%) D(f) Jc(c) Ai(c)">
#              <svg class="Fil(simpleListItemPlayIconFilter) Mstart(2px) Cur(p)" data-icon="CorePlay" height="26" style="fill:#fff;stroke:#fff;stroke-width:0;vertical-align:bottom" viewbox="0 0 512 512" width="24">
#               <path d="M82.294 490.295c-20.327 11.736-36.952 2.14-36.952-21.332V42.295c0-23.472 16.632-33.055 36.952-21.332L451.67 234.295c20.318 11.75 20.318 30.945 0 42.682L82.294 490.295z">
#               </path>
#              </svg>
#             </span>
#            </div>
#            <div class="simple-item-content">
#             <h4 class="C($titleColor) Fw(700) Fz(14px) M(0) Lh(1.71) Trs(colorTransition) item-hover-trigger:h_C($titleHoverColor)">
#              <a class="Td(n) C($inherit) LineClamp(3,80px) Mt(12px) js-content-viewer rapidnofollow" data-hosted-type="HOSTED" data-uuid="f88505e8-e3a5-354f-9f73-ed29fab87448" data-wf-caas-prefetch="1" data-wf-caas-uuid="f88505e8-e3a5-354f-9f73-ed29fab87448" data-ylk="sec:rr-stories;elm:hdln;pos:1;itc:0;cpos:11;ct:video;g:f88505e8-e3a5-354f-9f73-ed29fab87448" href="https://news.yahoo.com/warm-breezy-start-monday-002036448.html">
#               Warm, breezy start to Monday
#               <div class="StretchedBox Z(1)">
#               </div>
#              </a>
#             </h4>
#             <div class="provider-logo C($providerColor) Mt(4px) Fw(500) Fz(11px)">
#              <span class="D(ib) Mt(2px) Mb(4px)">
#               KNXV - Phoenix Scripps
#              </span>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li class="common simple-list-item-v2 stream-item D(n):e W(100%) Px(10px) Mb(30px) Bxz(bb) Fl(start) js-stream-content">
#           <div class="item-hover-trigger Pos(r)">
#            <div class="item-img-wrapper Pos(r) Ov(h) Fxs(0) Z(0) Bdrs(8px)">
#             <img alt="" class="D(b) W(100%) Mend(10px) Mah(168px) item-hover-trigger:h_Scale(1.05) Trs(listItemTransformTransition) wafer-img" data-wf-src="https://s.yimg.com/uu/api/res/1.2/zZzmfWTWCc_CneJ6cmO8IQ--~B/Zmk9c3RyaW07aD02MjQ7cT04MDt3PTEyMDA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/hd/cp-video-transcode/prod/2022-02/21/62130b849cc3ec43bf5612b0/62130b849cc3ec43bf5612b1_o_U_v2.jpg" src="https://s.yimg.com/cv/apiv2/default/20190501/placeholder.gif"/>
#             <span class="Pos(a) Start(50%) T(50%) Translate(translate50PerNeg) Bgi(simpleListItemPlayIconBgGradient) Bxsh(simpleListItemPlayIconBoxShadow) W(60px) H(60px) Bdrs(50%) D(f) Jc(c) Ai(c)">
#              <svg class="Fil(simpleListItemPlayIconFilter) Mstart(2px) Cur(p)" data-icon="CorePlay" height="26" style="fill:#fff;stroke:#fff;stroke-width:0;vertical-align:bottom" viewbox="0 0 512 512" width="24">
#               <path d="M82.294 490.295c-20.327 11.736-36.952 2.14-36.952-21.332V42.295c0-23.472 16.632-33.055 36.952-21.332L451.67 234.295c20.318 11.75 20.318 30.945 0 42.682L82.294 490.295z">
#               </path>
#              </svg>
#             </span>
#            </div>
#            <div class="simple-item-content">
#             <h4 class="C($titleColor) Fw(700) Fz(14px) M(0) Lh(1.71) Trs(colorTransition) item-hover-trigger:h_C($titleHoverColor)">
#              <a class="Td(n) C($inherit) LineClamp(3,80px) Mt(12px) js-content-viewer rapidnofollow" data-hosted-type="HOSTED" data-uuid="55328ef7-4e62-3072-afe2-7a4ff5a26e20" data-wf-caas-prefetch="1" data-wf-caas-uuid="55328ef7-4e62-3072-afe2-7a4ff5a26e20" data-ylk="sec:rr-stories;elm:hdln;pos:1;itc:0;cpos:12;ct:video;g:55328ef7-4e62-3072-afe2-7a4ff5a26e20" href="https://news.yahoo.com/sen-schumer-calls-bird-flu-033802675.html">
#               Sen. Schumer calls for bird flu awareness campaign
#               <div class="StretchedBox Z(1)">
#               </div>
#              </a>
#             </h4>
#             <div class="provider-logo C($providerColor) Mt(4px) Fw(500) Fz(11px)">
#              <span class="D(ib) Mt(2px) Mb(4px)">
#               CBS News Videos
#              </span>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li class="common simple-list-item-v2 stream-item D(n):e W(100%) Px(10px) Mb(30px) Bxz(bb) Fl(start) js-stream-content">
#           <div class="item-hover-trigger Pos(r)">
#            <div class="item-img-wrapper Pos(r) Ov(h) Fxs(0) Z(0) Bdrs(8px)">
#             <img alt="" class="D(b) W(100%) Mend(10px) Mah(168px) item-hover-trigger:h_Scale(1.05) Trs(listItemTransformTransition) wafer-img" data-wf-src="https://s.yimg.com/uu/api/res/1.2/9djBH6.h95xhTj02dkse0A--~B/Zmk9c3RyaW07aD02MjQ7cT04MDt3PTEyMDA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/hd/cp-video-transcode/prod/2022-02/21/6213ac772a1f5e788534f0c8/6213ac772a1f5e788534f0c9_o_U_v2.jpg" src="https://s.yimg.com/cv/apiv2/default/20190501/placeholder.gif"/>
#             <span class="Pos(a) Start(50%) T(50%) Translate(translate50PerNeg) Bgi(simpleListItemPlayIconBgGradient) Bxsh(simpleListItemPlayIconBoxShadow) W(60px) H(60px) Bdrs(50%) D(f) Jc(c) Ai(c)">
#              <svg class="Fil(simpleListItemPlayIconFilter) Mstart(2px) Cur(p)" data-icon="CorePlay" height="26" style="fill:#fff;stroke:#fff;stroke-width:0;vertical-align:bottom" viewbox="0 0 512 512" width="24">
#               <path d="M82.294 490.295c-20.327 11.736-36.952 2.14-36.952-21.332V42.295c0-23.472 16.632-33.055 36.952-21.332L451.67 234.295c20.318 11.75 20.318 30.945 0 42.682L82.294 490.295z">
#               </path>
#              </svg>
#             </span>
#            </div>
#            <div class="simple-item-content">
#             <h4 class="C($titleColor) Fw(700) Fz(14px) M(0) Lh(1.71) Trs(colorTransition) item-hover-trigger:h_C($titleHoverColor)">
#              <a class="Td(n) C($inherit) LineClamp(3,80px) Mt(12px) js-content-viewer rapidnofollow" data-hosted-type="HOSTED" data-uuid="9b1793f0-90da-3161-8885-a613beaa534d" data-wf-caas-prefetch="1" data-wf-caas-uuid="9b1793f0-90da-3161-8885-a613beaa534d" data-ylk="sec:rr-stories;elm:hdln;pos:1;itc:0;cpos:13;ct:video;g:9b1793f0-90da-3161-8885-a613beaa534d" href="https://news.yahoo.com/sf-school-board-mayor-london-150901352.html">
#               SF School Board:  Mayor London Breed details her selection process for new school members
#               <div class="StretchedBox Z(1)">
#               </div>
#              </a>
#             </h4>
#             <div class="provider-logo C($providerColor) Mt(4px) Fw(500) Fz(11px)">
#              <span class="D(ib) Mt(2px) Mb(4px)">
#               CBS-Sanfrancisco
#              </span>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li class="common simple-list-item-v2 stream-item D(n):e W(100%) Px(10px) Mb(30px) Bxz(bb) Fl(start) js-stream-content">
#           <div class="item-hover-trigger Pos(r)">
#            <div class="item-img-wrapper Pos(r) Ov(h) Fxs(0) Z(0) Bdrs(8px)">
#             <img alt="" class="D(b) W(100%) Mend(10px) Mah(168px) item-hover-trigger:h_Scale(1.05) Trs(listItemTransformTransition) wafer-img" data-wf-src="https://s.yimg.com/uu/api/res/1.2/5vNluUW1QWXiF2ys1FiciA--~B/Zmk9c3RyaW07aD0zMTI7cT05NTt3PTYwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/uu/api/res/1.2/avq9TL8beOMjkebCHGKIWw--~B/aD00NjQ7dz03OTU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/the_national_review_738/71f0bf428b2b63f673e1c3f1d3abee97" src="https://s.yimg.com/cv/apiv2/default/20190501/placeholder.gif"/>
#            </div>
#            <div class="simple-item-content">
#             <h4 class="C($titleColor) Fw(700) Fz(14px) M(0) Lh(1.71) Trs(colorTransition) item-hover-trigger:h_C($titleHoverColor)">
#              <a class="Td(n) C($inherit) LineClamp(3,80px) Mt(12px) js-content-viewer rapidnofollow" data-hosted-type="HOSTED" data-uuid="f3e77ab2-dccf-3a07-b3cd-b3f7a2070fbd" data-wf-caas-prefetch="1" data-wf-caas-uuid="f3e77ab2-dccf-3a07-b3cd-b3f7a2070fbd" data-ylk="sec:rr-stories;elm:hdln;pos:1;itc:0;cpos:14;ct:story;g:f3e77ab2-dccf-3a07-b3cd-b3f7a2070fbd" href="https://news.yahoo.com/pentagon-anticipates-imminent-russian-invasion-212218980.html">
#               Russia Orders Troops to Ukrainian Separatist Regions following Putin Recognition
#               <div class="StretchedBox Z(1)">
#               </div>
#              </a>
#             </h4>
#             <div class="provider-logo C($providerColor) Mt(4px) Fw(500) Fz(11px)">
#              <span class="D(ib) Mt(2px) Mb(4px)">
#               National Review
#              </span>
#             </div>
#            </div>
#           </div>
#          </li>
#         </ul>
#        </div>
#        <script class="wafer-state" type="application/json">
#         {"geminiAds":{"geminiDedupeToken":"PHToken"}}
#        </script>
#       </div>
#       <script>
#        window.performance.mark('rightrailStories');
#                     window.performance.measure('rightrailStoriesDone','PageStart','rightrailStories');
#       </script>
#      </div>
#     </div>
#     <div class="sticky-sda-container wafer wafer-sticky Fxg(1)" data-wf-sticky-boundary="aside-section" data-wf-sticky-offset="165px   10px" data-wf-sticky-target=".sticky-sda">
#      <div class="sticky-sda">
#       <div class="Mb($gridMargin) Mt(25px) LREC3-status-error" id="sda-LREC3">
#        <div id="sda-LREC3-iframe">
#         <noscript>
#          <!-- SpaceID=0 robot -->
#         </noscript>
#        </div>
#       </div>
#       <div class="Mb($gridMargin) Mt(25px) LREC4-status-error" id="sda-LREC4">
#        <div id="sda-LREC4-iframe">
#         <noscript>
#          <!-- SpaceID=0 robot -->
#         </noscript>
#        </div>
#       </div>
#       <div class="Mb($gridMargin) Mt(25px) MON2-status-error" id="sda-MON2">
#        <div id="sda-MON2-iframe">
#         <noscript>
#          <!-- SpaceID=0 robot -->
#         </noscript>
#        </div>
#       </div>
#      </div>
#     </div>
#    </aside>
#   </main>
#  </div>
# </div>

# %%
final = master.find("div", class_="caas-body")
print(final.text)
# Out:
# With Thanksgiving in the rear-view mirror (even with turkey leftovers still in the fridge), we’re starting to look forward to Jacksonville’s dining scene in 2022.Among the new restaurants slated to open next year is Sugar Factory American Brasserie at the Markets at Town Center, where diners can (really) treat themselves to $25, celebrity-endorsed Couture Pops and a $99, 24-scoop ice cream sundae. (Really.) But Sugar Factory is more than just heaps and heaps of sugar, the Times-Union's Teresa Stepzinski reports. A spring opening is planned.Nearby at the St. Johns Town Center, work is underway at Fresh Mex & Co., a fast-casual urban grill and cantina set to take over the former Select Comfort spot between P.F. Chang’s China Bistro and M Shack. The restaurant will be the second location for Amanda and Michael Toussaint’s Tex-Mex cantina concept, which launched in 2017 at 7111 Bonneval Road.Also coming next year is the second of as many as nine Huey Magoo’s locations planned for the greater Jacksonville area. After opening his first restaurant in mid-October at South Beach Regional shopping center in Jacksonville Beach, franchisee Michael Phillips is eyeing the former Bank of America spot at Old St. Augustine and Hartley roads in Mandarin for his next location. Known for its cooked-to-order chicken tenders, Central Florida-based Huey Magoo’s has plans to add 200 restaurants in Florida and eight other states. (Another franchise group is planning a restaurant in St. Augustine at a former Krystal site.)See you soon, Singleton's: After more than 50 years, Singleton's Seafood Shack is temporarily closing. A week ago, the restaurant broke the news to diners on Facebook: "It’s with a sad heart that myself and family here at Singleton’s will have to close until we finish our renovations on the restaurant, we are working super hard to get back open fully so you can enjoy what we all here at Singleton’s want and expect you to enjoy." In 1969, Capt. Ray and Ann Singleton first began serving breakfast and lunch to Mayport's shrimpers out of a 20-by-20 building. They added dinner and more dining space. And more diners followed, including celebrity chef Guy Fieri, who stopped by with a production crew in 2010 for an episode of the Food Network's "Diners, Drive-ins and Dives."Story continuesWhere’s all the Jewish food in Jacksonville? That's the question Times-Union reporter Emily Bloch recently asked (and answered). If you thought the city’s challah supply disappeared with the closing (and subsequent demolition) of Worman’s Bakery in 2009, you’ll be glad to know there are some worthy successors. And to those who celebrate, Happy Hanukkah.More: 5 must-try Jewish foods in JacksonvilleAttention restaurant owners: If you plan to open on Christmas Day, share your dining plans with us using this form. For other news, please email gmills@jacksonville.com.And for those who still have turkey leftovers in the fridge, throw them out and head out to your favorite restaurant or find a new one.For more dining news, keep reading using the links below.Cheers!Gary MillsDeputy Managing EditorThe Florida Times-UnionEmail: gmills@jacksonville.comTwitter: @garytmillsThis article originally appeared on Florida Times-Union: Something (really) sweet is headed this way

# %%
sum_urls = filter_urls[0:10]
sum_urls
# Out:
# 25     https://finance.yahoo.com/news/shareholder-ale...
# 72     https://news.yahoo.com/something-really-sweet-...
# 171    https://news.yahoo.com/myles-gaskin-230745925....
# 173    https://news.yahoo.com/lawsuit-alleges-marylan...
# 176    https://finance.yahoo.com/news/shareholder-ale...
# 191    https://news.yahoo.com/care-move-outreach-gear...
# 259    https://news.yahoo.com/ezekiel-elliott-2313547...
# 292    https://au.finance.yahoo.com/news/putin-gives-...
# 332    https://finance.yahoo.com/news/rf-elements-ann...
# 336    https://news.yahoo.com/student-shares-she-saw-...
# Name: 4, dtype: object

# %%
from bs4 import BeautifulSoup
import requests
ls = []
for i in range(len(sum_urls)): #filter_urls
    URL = sum_urls.iloc[i] # filter_urls
    page = requests.get(URL,headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'})
    soup = BeautifulSoup(page.content, "html.parser")
    try:
        try:
            master = soup.find(id="Masterwrap")
            final = master.find("div", class_="caas-body")
        except AttributeError:
            master = soup.find(id="Masterwrap2Col")
            final = master.find("div", class_="caas-body")
    except AttributeError:
        ls.append(URL)
        pass

# %%
ls
# Out:
# ['https://news.yahoo.com/myles-gaskin-230745925.html',
#  'https://news.yahoo.com/ezekiel-elliott-231354757.html',
#  'https://news.yahoo.com/student-shares-she-saw-during-222800273.html']

# %%
filter_urls.iloc[0]
# Out:
# 'https://finance.yahoo.com/news/shareholder-alert-pomerantz-law-firm-231800401.html'

# %%
URL = filter_urls.iloc[0]
page = requests.get(URL,headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'})
soup = BeautifulSoup(page.content, "html.parser")
try:
    try:
        master = soup.find(id="Masterwrap")
        final = master.find("div", class_="caas-body")
    except AttributeError:
        master = soup.find(id="Masterwrap2Col")
        final = master.find("div", class_="caas-body")
except AttributeError:
    ls.append(URL)
    pass
final.text
# Out:
# 'NEW YORK, Nov. 30, 2021 (GLOBE NEWSWIRE) -- Pomerantz LLP announces that a class action lawsuit has been filed against BioMarin Pharmaceutical Inc. (“BioMarin” or the “Company”) (NASDAQ: BMRN) and certain of its officers. The class action, filed in the United States District Court for the Northern District of California, and docketed under 21-cv-08254, is on behalf of a class consisting of all persons and entities other than Defendants that purchased or otherwise acquired BioMarin securities between January 13, 2020 and September 3, 2021, both dates inclusive (the “Class Period”), seeking to recover damages caused by Defendants’ violations of the federal securities laws and to pursue remedies under Sections 10(b) and 20(a) of the Securities Exchange Act of 1934 (the “Exchange Act”) and Rule 10b-5 promulgated thereunder, against the Company and certain of its top officials.If you are a shareholder who purchased or otherwise acquired BioMarin securities during the Class Period, you have until December 22, 2021 to ask the Court to appoint you as Lead Plaintiff for the class. A copy of the Complaint can be obtained at www.pomerantzlaw.com. To discuss this action, contact Robert S. Willoughby at newaction@pomlaw.com or 888.476.6529 (or 888.4-POMLAW), toll-free, Ext. 7980. Those who inquire by e-mail are encouraged to include their mailing address, telephone number, and the number of shares purchased.[Click here for information about joining the class action]BioMarin develops and commercializes therapies for people with serious and life-threatening rare diseases and medical conditions. The Company is developing, among other product candidates, BMN 307, an AAV5 mediated gene therapy, which is in a phase 1/2 clinical trial to normalize blood phenylalanine concentration levels in patients with phenylketonuria (“PKU”). The Company’s Phearless Phase 1/2 study is evaluating BMN 307 in adults with PKU.On November 7, 2018, BioMarin shared pre-clinical data of BMN 307, which demonstrated lifetime Phe corrections in mouse models, and announced that the Company was planning to file an investigational new drug application (“IND”) for BMN 307 with the United States Food and Drug Administration (“FDA”) in the second half of 2019. On January 13, 2020, the Company announced that the FDA granted IND status for BMN 307 for the treatment of PKU. On September 24, 2020, the Company announced that it had dosed the first human participant in the global Phearless Phase 1/2 study of BMN 307.Story continuesThe complaint alleges that, throughout the Class Period, Defendants made materially false and misleading statements regarding the Company’s business, operations, and compliance policies. Specifically, Defendants made false and/or misleading statements and/or failed to disclose that: (i) BMN 307 was less safe than BioMarin had led investors to believe; (ii) BMN 307’s safety profile made it likely that the FDA would place a clinical hold on the Phearless Phase 1/2 study; (iii) accordingly, the Company had overstated BMN 307’s clinical and commercial prospects; and (iv) as a result, the Company’s public statements were materially false and misleading at all relevant times.On September 5, 2021, BioMarin issued a press release announcing, “that the [FDA] placed a clinical hold on the BMN 307 Phearless Phase 1/2 study”, which “is evaluating BMN 307, an investigational AAV5-phenylalanine hydroxylase (PAH) gene therapy, in adults with [PKU].” BioMarin advised investors that “[t]he FDA’s clinical hold was based on interim safety findings from a pre-clinical, non-GLP pharmacology study.”On this news, BioMarin’s stock price fell $7.14 per share, or 8.4%, to close at $77.81 per share on September 7, 2021, the next trading day.Pomerantz LLP, with offices in New York, Chicago, Los Angeles, Paris, and Tel Aviv, is acknowledged as one of the premier firms in the areas of corporate, securities, and antitrust class litigation. Founded by the late Abraham L. Pomerantz, know ...
