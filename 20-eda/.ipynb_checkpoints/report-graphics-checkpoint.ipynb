# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Website-Count" data-toc-modified-id="Website-Count-1">Website Count</a></span></li><li><span><a href="#Readability-Correlation-Plot" data-toc-modified-id="Readability-Correlation-Plot-2">Readability Correlation Plot</a></span></li><li><span><a href="#Article-Tags-Count" data-toc-modified-id="Article-Tags-Count-3">Article Tags Count</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Website Count

# %%
gdelt_df = pd.read_csv("web-count_jan2021.csv", index_col=[0]) 
gdelt_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-53542e9577c6> in <module>
# ----> 1 gdelt_df = pd.read_csv("web-count_jan2021.csv", index_col=[0])
#       2 gdelt_df.head()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'web-count_jan2021.csv'

# %%
gdelt_df.columns

# %%
website_count_df = pd.DataFrame(gdelt_df.website.value_counts().rename_axis('Website').reset_index(name='Count'))
website_count_df[0:20]

# %%
website_count_df.to_excel("website_counts.xlsx")

# %% [markdown]
# ## Readability Correlation Plot

# %%
nlp_df = pd.read_csv("../00-data/aws_data/nlp_jan2021.csv") # update with finalized df
nlp_df.head(5)
# Out:
#    year  month  day    website  \
# 0  2021      1    1  yahoo.com
# 1  2021      1    1  yahoo.com
# 2  2021      1    1  yahoo.com
# 3  2021      1    1  yahoo.com
# 4  2021      1    1  yahoo.com
#
#                                                  url  pos_mean  pos_median  \
# 0  https://news.yahoo.com/amazon-fire-tv-india-23...      0.00         0.0
# 1  https://news.yahoo.com/red-hot-buccaneers-not-...      0.22         0.0
# 2  https://news.yahoo.com/walt-disney-dis-gains-l...      0.37         0.0
# 3  https://news.yahoo.com/walt-disney-dis-gains-l...      0.37         0.0
# 4  https://news.yahoo.com/walt-disney-dis-gains-l...      0.37         0.0
#
#    pos_min  pos_max  neg_mean  ...  Coleman-Liau  FleschReadingEase  \
# 0      0.0      0.0      0.00  ...          8.59              83.65
# 1      0.0      1.0      0.12  ...          7.41              88.32
# 2      0.0      1.0      0.15  ...          9.76              72.06
# 3      0.0      1.0      0.15  ...          9.76              72.06
# 4      0.0      1.0      0.15  ...          9.76              72.06
#
#    GunningFogIndex    LIX  SMOGIndex   RIX  DaleChallIndex  words  \
# 0            10.37  38.30       9.32  3.67           10.44  113.0
# 1             9.84  33.51       9.01  2.79            9.47  696.0
# 2            13.99  44.09      12.55  4.76           13.10  472.0
# 3            13.99  44.09      12.55  4.76           13.10  472.0
# 4            13.99  44.09      12.55  4.76           13.10  472.0
#
#    complex_words  tags
# 0            8.0  AMZN
# 1           47.0     T
# 2           76.0   DIS
# 3           76.0   DOW
# 4           76.0  NDAQ
#
# [5 rows x 33 columns]

# %%
read_cols = ['Kincaid', 'ARI', 'Coleman-Liau',
       'FleschReadingEase', 'GunningFogIndex', 'LIX', 'SMOGIndex', 'RIX',
       'DaleChallIndex']
read_word_cols = read_cols + ['words', 'complex_words']

# %%
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(nlp_df[read_cols].to_numpy())
df_scaled = pd.DataFrame(df_scaled, columns=read_cols)
df_scaled.head()
# Out:
#     Kincaid       ARI  Coleman-Liau  FleschReadingEase  GunningFogIndex  \
# 0  0.283100  0.242230      0.611583           0.626997         0.195996
# 1  0.264597  0.218441      0.582127           0.651953         0.184205
# 2  0.316612  0.258725      0.640789           0.565062         0.276529
# 3  0.316612  0.258725      0.640789           0.565062         0.276529
# 4  0.316612  0.258725      0.640789           0.565062         0.276529
#
#         LIX  SMOGIndex       RIX  DaleChallIndex
# 0  0.199843   0.223260  0.097302        0.239575
# 1  0.158169   0.210102  0.072044        0.160262
# 2  0.250218   0.360357  0.128588        0.457073
# 3  0.250218   0.360357  0.128588        0.457073
# 4  0.250218   0.360357  0.128588        0.457073

# %%
df_scaled.columns
# Out:
# Index(['Kincaid', 'ARI', 'Coleman-Liau', 'FleschReadingEase',
#        'GunningFogIndex', 'LIX', 'SMOGIndex', 'RIX', 'DaleChallIndex'],
#       dtype='object')

# %%
corr = df_scaled.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_dd02c_row0_col0, #T_dd02c_row1_col1, #T_dd02c_row2_col2, #T_dd02c_row3_col3, #T_dd02c_row4_col4, #T_dd02c_row5_col5, #T_dd02c_row6_col6, #T_dd02c_row7_col7, #T_dd02c_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_dd02c_row0_col1, #T_dd02c_row1_col0 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_dd02c_row0_col2, #T_dd02c_row2_col0 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_dd02c_row0_col3, #T_dd02c_row3_col0, #T_dd02c_row3_col1, #T_dd02c_row3_col2, #T_dd02c_row3_col4, #T_dd02c_row3_col5, #T_dd02c_row3_col6, #T_dd02c_row3_col7, #T_dd02c_row3_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_dd02c_row0_col4, #T_dd02c_row4_col0, #T_dd02c_row5_col7, #T_dd02c_row7_col5 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_dd02c_row0_col5, #T_dd02c_row1_col7, #T_dd02c_row5_col0, #T_dd02c_row7_col1 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_dd02c_row0_col6 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_dd02c_row0_col7, #T_dd02c_row7_col0, #T_dd02c_row7_col4 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_dd02c_row0_col8 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_dd02c_row1_col2, #T_dd02c_row2_col1 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_dd02c_row1_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_dd02c_row1_col4, #T_dd02c_row4_col1 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_dd02c_row1_col5, #T_dd02c_row4_col6, #T_dd02c_row5_col1, #T_dd02c_row6_col4 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_dd02c_row1_col6 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_dd02c_row1_col8 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_dd02c_row2_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_dd02c_row2_col4 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_dd02c_row2_col5 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_dd02c_row2_col6, #T_dd02c_row6_col2 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_dd02c_row2_col7 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_dd02c_row2_col8 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_dd02c_row4_col2 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_dd02c_row4_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_dd02c_row4_col5, #T_dd02c_row4_col7, #T_dd02c_row5_col4, #T_dd02c_row6_col0 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_dd02c_row4_col8 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_dd02c_row5_col2 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_dd02c_row5_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_dd02c_row5_col6, #T_dd02c_row6_col5 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_dd02c_row5_col8 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_dd02c_row6_col1 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_dd02c_row6_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_dd02c_row6_col7, #T_dd02c_row7_col6 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_dd02c_row6_col8 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_dd02c_row7_col2 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_dd02c_row7_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_dd02c_row7_col8 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_dd02c_row8_col0 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_dd02c_row8_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_dd02c_row8_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_dd02c_row8_col3 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_dd02c_row8_col4 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_dd02c_row8_col5 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_dd02c_row8_col6 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_dd02c_row8_col7 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# </style>
# <table id="T_dd02c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Kincaid</th>
#       <th class="col_heading level0 col1" >ARI</th>
#       <th class="col_heading level0 col2" >Coleman-Liau</th>
#       <th class="col_heading level0 col3" >FleschReadingEase</th>
#       <th class="col_heading level0 col4" >GunningFogIndex</th>
#       <th class="col_heading level0 col5" >LIX</th>
#       <th class="col_heading level0 col6" >SMOGIndex</th>
#       <th class="col_heading level0 col7" >RIX</th>
#       <th class="col_heading level0 col8" >DaleChallIndex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd02c_level0_row0" class="row_heading level0 row0" >Kincaid</th>
#       <td id="T_dd02c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_dd02c_row0_col1" class="data row0 col1" >0.988471</td>
#       <td id="T_dd02c_row0_col2" class="data row0 col2" >0.831758</td>
#       <td id="T_dd02c_row0_col3" class="data row0 col3" >-0.956866</td>
#       <td id="T_dd02c_row0_col4" class="data row0 col4" >0.964974</td>
#       <td id="T_dd02c_row0_col5" class="data row0 col5" >0.975740</td>
#       <td id="T_dd02c_row0_col6" class="data row0 col6" >0.939366</td>
#       <td id="T_dd02c_row0_col7" class="data row0 col7" >0.951651</td>
#       <td id="T_dd02c_row0_col8" class="data row0 col8" >0.236695</td>
#     </tr>
#     <tr>
#       <th id="T_dd02c_level0_row1" class="row_heading level0 row1" >ARI</th>
#       <td id="T_dd02c_row1_col0" class="data row1 col0" >0.988471</td>
#       <td id="T_dd02c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_dd02c_row1_col2" class="data row1 col2" >0.799514</td>
#       <td id="T_dd02c_row1_col3" class="data row1 col3" >-0.919328</td>
#       <td id="T_dd02c_row1_col4" class="data row1 col4" >0.958701</td>
#       <td id="T_dd02c_row1_col5" class="data row1 col5" >0.984436</td>
#       <td id="T_dd02c_row1_col6" class="data row1 col6" >0.917556</td>
#       <td id="T_dd02c_row1_col7" class="data row1 col7" >0.971520</td>
#       <td id="T_dd02c_row1_col8" class="data row1 col8" >0.308263</td>
#     </tr>
#     <tr>
#       <th id="T_dd02c_level0_row2" class="row_heading level0 row2" >Coleman-Liau</th>
#       <td id="T_dd02c_row2_col0" class="data row2 col0" >0.831758</td>
#       <td id="T_dd02c_row2_col1" class="data row2 col1" >0.799514</td>
#       <td id="T_dd02c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_dd02c_row2_col3" class="data row2 col3" >-0.904745</td>
#       <td id="T_dd02c_row2_col4" class="data row2 col4" >0.755775</td>
#       <td id="T_dd02c_row2_col5" class="data row2 col5" >0.813477</td>
#       <td id="T_dd02c_row2_col6" class="data row2 col6" >0.792670</td>
#       <td id="T_dd02c_row2_col7" class="data row2 col7" >0.692166</td>
#       <td id="T_dd02c_row2_col8" class="data row2 col8" >0.087108</td>
#     </tr>
#     <tr>
#       <th id="T_dd02c_level0_row3" class="row_heading level0 row3" >FleschReadingEase</th>
#       <td id="T_dd02c_row3_col0" class="data row3 col0" >-0.956866</td>
#       <td id="T_dd02c_row3_col1" class="data row3 col1" >-0.919328</td>
#       <td id="T_dd02c_row3_col2" class="data row3 col2" >-0.904745</td>
#       <td id="T_dd02c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_dd02c_row3_col4" class="data row3 col4" >-0.891930</td>
#       <td id="T_dd02c_row3_col5" class="data row3 col5" >-0.929708</td>
#       <td id="T_dd02c_row3_col6" class="data row3 col6" >-0.900402</td>
#       <td id="T_dd02c_row3_col7" class="data row3 col7" >-0.847148</td>
#       <td id="T_dd02c_row3_col8" class="data row3 col8" >-0.214506</td>
#     </tr>
#     <tr>
#       <th id="T_dd02c_level0_row4" class="row_heading level0 row4" >GunningFogIndex</th>
#       <td id="T_dd02c_row4_col0" class="data row4 col0" >0.964974</td>
#       <td id="T_dd02c_row4_col1" class="data row4 col1" >0.958701</td>
#       <td id="T_dd02c_row4_col2" class="data row4 col2" >0.755775</td>
#       <td id="T_dd02c_row4_col3" class="data row4 col3" >-0.891930</td>
#       <td id="T_dd02c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_dd02c_row4_col5" class="data row4 col5" >0.942725</td>

# %%
df_scaled = scaler.fit_transform(nlp_df[read_word_cols].to_numpy())
df_scaled = pd.DataFrame(df_scaled, columns=read_word_cols)
corr = df_scaled.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d35b4_row0_col0, #T_d35b4_row1_col1, #T_d35b4_row2_col2, #T_d35b4_row3_col3, #T_d35b4_row4_col4, #T_d35b4_row5_col5, #T_d35b4_row6_col6, #T_d35b4_row7_col7, #T_d35b4_row8_col8, #T_d35b4_row9_col9, #T_d35b4_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d35b4_row0_col1, #T_d35b4_row1_col0 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_d35b4_row0_col2, #T_d35b4_row2_col0 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_d35b4_row0_col3, #T_d35b4_row2_col9, #T_d35b4_row3_col0, #T_d35b4_row3_col1, #T_d35b4_row3_col2, #T_d35b4_row3_col4, #T_d35b4_row3_col5, #T_d35b4_row3_col6, #T_d35b4_row3_col7, #T_d35b4_row3_col8, #T_d35b4_row3_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d35b4_row0_col4, #T_d35b4_row4_col0, #T_d35b4_row5_col7, #T_d35b4_row7_col5 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_d35b4_row0_col5, #T_d35b4_row1_col7, #T_d35b4_row5_col0, #T_d35b4_row7_col1 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_d35b4_row0_col6 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_d35b4_row0_col7, #T_d35b4_row7_col0, #T_d35b4_row7_col4 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_d35b4_row0_col8, #T_d35b4_row9_col2 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_d35b4_row0_col9 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_d35b4_row0_col10, #T_d35b4_row1_col10 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_d35b4_row1_col2, #T_d35b4_row2_col1 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_d35b4_row1_col3, #T_d35b4_row2_col10 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_d35b4_row1_col4, #T_d35b4_row4_col1 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_d35b4_row1_col5, #T_d35b4_row4_col6, #T_d35b4_row5_col1, #T_d35b4_row6_col4 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_d35b4_row1_col6 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_d35b4_row1_col8 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_d35b4_row1_col9, #T_d35b4_row6_col9 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_d35b4_row2_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_d35b4_row2_col4 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_d35b4_row2_col5 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_d35b4_row2_col6, #T_d35b4_row6_col2 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_d35b4_row2_col7 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_d35b4_row2_col8 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_d35b4_row3_col9, #T_d35b4_row6_col8, #T_d35b4_row10_col8 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_d35b4_row4_col2 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_d35b4_row4_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_d35b4_row4_col5, #T_d35b4_row4_col7, #T_d35b4_row5_col4, #T_d35b4_row6_col0 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_d35b4_row4_col8 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_d35b4_row4_col9 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_d35b4_row4_col10 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_d35b4_row5_col2 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_d35b4_row5_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_d35b4_row5_col6, #T_d35b4_row6_col5 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_d35b4_row5_col8 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_d35b4_row5_col9 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_d35b4_row5_col10 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_d35b4_row6_col1 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_d35b4_row6_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_d35b4_row6_col7, #T_d35b4_row7_col6 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_d35b4_row6_col10 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_d35b4_row7_col2 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_d35b4_row7_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_d35b4_row7_col8 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_d35b4_row7_col9 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_d35b4_row7_col10 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_d35b4_row8_col0 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_d35b4_row8_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_d35b4_row8_col2, #T_d35b4_row10_col6 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_d35b4_row8_col3 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_d35b4_row8_col4 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_d35b4_row8_col5 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_d35b4_row8_col6 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_d35b4_row8_col7 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_d35b4_row8_col9 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_d35b4_row8_col10 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_d35b4_row9_col0, #T_d35b4_row9_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_d35b4_row9_col3 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_d35b4_row9_col4 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_d35b4_row9_col5 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_d35b4_row9_col6, #T_d35b4_row9_col7 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_d35b4_row9_col8 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_d35b4_row9_col10 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_d35b4_row10_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_d35b4_row10_col1 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_d35b4_row10_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_d35b4_row10_col3 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_d35b4_row10_col4 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_d35b4_row10_col5 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_d35b4_row10_col7 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_d35b4_row10_col9 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d35b4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Kincaid</th>
#       <th class="col_heading level0 col1" >ARI</th>
#       <th class="col_heading level0 col2" >Coleman-Liau</th>
#       <th class="col_heading level0 col3" >FleschReadingEase</th>
#       <th class="col_heading level0 col4" >GunningFogIndex</th>
#       <th class="col_heading level0 col5" >LIX</th>
#       <th class="col_heading level0 col6" >SMOGIndex</th>
#       <th class="col_heading level0 col7" >RIX</th>
#       <th class="col_heading level0 col8" >DaleChallIndex</th>
#       <th class="col_heading level0 col9" >words</th>
#       <th class="col_heading level0 col10" >complex_words</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d35b4_level0_row0" class="row_heading level0 row0" >Kincaid</th>
#       <td id="T_d35b4_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d35b4_row0_col1" class="data row0 col1" >0.988471</td>
#       <td id="T_d35b4_row0_col2" class="data row0 col2" >0.831758</td>
#       <td id="T_d35b4_row0_col3" class="data row0 col3" >-0.956866</td>
#       <td id="T_d35b4_row0_col4" class="data row0 col4" >0.964974</td>
#       <td id="T_d35b4_row0_col5" class="data row0 col5" >0.975740</td>
#       <td id="T_d35b4_row0_col6" class="data row0 col6" >0.939366</td>
#       <td id="T_d35b4_row0_col7" class="data row0 col7" >0.951651</td>
#       <td id="T_d35b4_row0_col8" class="data row0 col8" >0.236695</td>
#       <td id="T_d35b4_row0_col9" class="data row0 col9" >-0.118046</td>
#       <td id="T_d35b4_row0_col10" class="data row0 col10" >0.028791</td>
#     </tr>
#     <tr>
#       <th id="T_d35b4_level0_row1" class="row_heading level0 row1" >ARI</th>
#       <td id="T_d35b4_row1_col0" class="data row1 col0" >0.988471</td>
#       <td id="T_d35b4_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d35b4_row1_col2" class="data row1 col2" >0.799514</td>
#       <td id="T_d35b4_row1_col3" c

# %%
df = df_scaled.round(2) # with word counts
fig, ax = plt.subplots(figsize=(6, 5))
sns.heatmap(df.corr(method='pearson'), annot=True, fmt='.2f', 
            cmap=plt.get_cmap('coolwarm'), cbar=False, ax=ax)
ax.set_yticklabels(ax.get_yticklabels(), rotation="horizontal")
plt.savefig('result.png', bbox_inches='tight', pad_inches=0.0)

# %% [markdown]
# ## Article Tags Count

# %%
tag_count_df = pd.DataFrame(nlp_df.tags.value_counts().rename_axis('Tags').reset_index(name='Count'))
tag_count_df.head(10)
# Out:
#    Tags  Count
# 0     T   5270
# 1  TWTR   3290
# 2  NDAQ   3066
# 3   COF   2543
# 4   TGT   2055
# 5  SPGI   1487
# 6    RF   1284
# 7   PFG   1150
# 8   DOW   1101
# 9  AMZN    874

# %%
plt.barh(tag_count_df.Tags[0:15], tag_count_df.Count[0:15])
# Out:
# <BarContainer object of 15 artists>
