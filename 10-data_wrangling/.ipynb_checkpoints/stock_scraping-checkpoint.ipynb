# %%
import pandas as pd
import time
from os.path import exists
# There are 2 tables on the Wikipedia page
# we want the first table

tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
sp500_df = tables[0]
sp500_df
# Out:
#     Symbol            Security SEC filings             GICS Sector  \
# 0      MMM                  3M     reports             Industrials
# 1      AOS         A. O. Smith     reports             Industrials
# 2      ABT              Abbott     reports             Health Care
# 3     ABBV              AbbVie     reports             Health Care
# 4     ABMD             Abiomed     reports             Health Care
# ..     ...                 ...         ...                     ...
# 500    YUM         Yum! Brands     reports  Consumer Discretionary
# 501   ZBRA  Zebra Technologies     reports  Information Technology
# 502    ZBH       Zimmer Biomet     reports             Health Care
# 503   ZION       Zions Bancorp     reports              Financials
# 504    ZTS              Zoetis     reports             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota
# 1                     Building Products     Milwaukee, Wisconsin
# 2                 Health Care Equipment  North Chicago, Illinois
# 3                       Pharmaceuticals  North Chicago, Illinois
# 4                 Health Care Equipment   Danvers, Massachusetts
# ..                                  ...                      ...
# 500                         Restaurants     Louisville, Kentucky
# 501  Electronic Equipment & Instruments   Lincolnshire, Illinois
# 502               Health Care Equipment          Warsaw, Indiana
# 503                      Regional Banks     Salt Lake City, Utah
# 504                     Pharmaceuticals   Parsippany, New Jersey
#
#     Date first added      CIK      Founded
# 0         1976-08-09    66740         1902
# 1         2017-07-26    91142         1916
# 2         1964-03-31     1800         1888
# 3         2012-12-31  1551152  2013 (1888)
# 4         2018-05-31   815094         1981
# ..               ...      ...          ...
# 500       1997-10-06  1041061         1997
# 501       2019-12-23   877212         1969
# 502       2001-08-07  1136869         1927
# 503       2001-06-22   109380         1873
# 504       2013-06-21  1555280         1952
#
# [505 rows x 9 columns]

# %%
tickers = sp500_df.loc[:,'Symbol']
tickers = tickers.to_list()
tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADM',
#  'ADBE',
#  'ADP',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'AIG',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AMD',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BLL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
#  'CNP',
#  'CDAY',
#  'CERN',
#  'CF',
#  'CRL',
#  'SCHW',
#  'CHTR',
#  'CVX',
#  'CMG',
#  'CB',
#  'CHD',
#  'CI',
#  'CINF',
#  'CTAS',
#  'CSCO',
#  'C',
#  'CFG',
#  'CTXS',
#  'CLX',
#  'CME',
#  'CMS',
#  'KO',
#  'CTSH',
#  'CL',
#  'CMCSA',
#  'CMA',
#  'CAG',
#  'COP',
#  'ED',
#  'STZ',
#  'COO',
#  'CPRT',
#  'GLW',
#  'CTVA',
#  'COST',
#  'CTRA',
#  'CCI',
#  'CSX',
#  'CMI',
#  'CVS',
#  'DHI',
#  'DHR',
#  'DRI',
#  'DVA',
#  'DE',
#  'DAL',
#  'XRAY',
#  'DVN',
#  'DXCM',
#  'FANG',
#  'DLR',
#  'DFS',
#  'DISCA',
#  'DISCK',
#  'DISH',
#  'DG',
#  'DLTR',
#  'D',
#  'DPZ',
#  'DOV',
#  'DOW',
#  'DTE',
#  'DUK',
#  'DRE',
#  'DD',
#  'DXC',
#  'EMN',
#  'ETN',
#  'EBAY',
#  'ECL',
#  'EIX',
#  'EW',
#  'EA',
#  'EMR',
#  'ENPH',
#  'ETR',
#  'EOG',
#  'EPAM',
#  'EFX',
#  'EQIX',
#  'EQR',
#  'ESS',
#  'EL',
#  'ETSY',
#  'RE',
#  'EVRG',
#  'ES',
#  'EXC',
#  'EXPE',
#  'EXPD',
#  'EXR',
#  'XOM',
#  'FFIV',
#  'FDS',
#  'FAST',
#  'FRT',
#  'FDX',
#  'FITB',
#  'FRC',
#  'FE',
#  'FIS',
#  'FISV',
#  'FLT',
#  'FMC',
#  'F',
#  'FTNT',
#  'FTV',
#  'FBHS',
#  'FOXA',
#  'FOX',
#  'BEN',
#  'FCX',
#  'GPS',
#  'GRMN',
#  'IT',
#  'GE',
#  'GNRC',
#  'GD',
#  'GIS',
#  'GPC',
#  'GILD',
#  'GL',
#  'GPN',
#  'GM',
#  'GS',
#  'GWW',
#  'HAL',
#  'HIG',
#  'HAS',
#  'HCA',
#  'PEAK',
#  'HSIC',
#  'HSY',
#  'HES',
#  'HPE',
#  'HLT',
#  'HOLX',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HWM',
#  'HPQ',
#  'HUM',
#  'HBAN',
#  'HII',
#  'IEX',
#  'IDXX',
#  'INFO',
#  'ITW',
#  'ILMN',
#  'INCY',
#  'IR',
#  'INTC',
#  'ICE',
#  'IBM',
#  'IP',
#  'IPG',
#  'IFF',
#  'INTU',
#  'ISRG',
#  'IVZ',
#  'IPGP',
#  'IQV',
#  'IRM',
#  'JKHY',
#  'J',
#  'JBHT',
#  'SJM',
#  'JNJ',
#  'JCI',
#  'JPM',
#  'JNPR',
#  'K',
#  'KEY',
#  'KEYS',
#  'KMB',
#  'KIM',
#  'KMI',
#  'KLAC',
#  'KHC',
#  'KR',
#  'LHX',
#  'LH',
#  'LRCX',
#  'LW',
#  'LVS',
#  'LDOS',
#  'LEN',
#  'LLY',
#  'LNC',
#  'LIN',
#  'LYV',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LUMN',
#  'LYB',
#  'MTB',
#  'MRO',
#  'MPC',
#  'MKTX',
#  'MAR',
#  'MMC',
#  'MLM',
#  'MAS',
#  'MA',
#  'MTCH',
#  'MKC',
#  'MCD',
#  'MCK',
#  'MDT',
#  'MRK',
#  'FB',
#  'MET',
#  'MTD',
#  'MGM',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MAA',
#  'MRNA',
#  'MHK',
#  'TAP',
#  'MDLZ',
#  'MPWR',
#  'MNST',
#  'MCO',
#  'MS',
#  'MOS',
#  'MSI',
#  'MSCI',
#  'NDAQ',
#  'NTAP',
#  'NFLX',
#  'NWL',
#  'NEM',
#  'NWSA',
#  'NWS',
#  'NEE',
#  'NLSN',
#  'NKE',
#  'NI',
#  'NSC',
#  'NTRS',
#  'NOC',
#  'NLOK',
#  'NCLH',
#  'NRG',
#  'NUE',
#  'NVDA',
#  'NVR',
#  'NXPI',
#  'ORLY',
#  'OXY',
#  'ODFL',
#  'OMC',
#  'OKE',
#  'ORCL',
#  'OGN',
#  'OTIS',
#  'PCAR',
#  'PKG',
#  'PH',
#  'PAYX',
#  'PAYC',
#  'PYPL',
#  'PENN',
#  'PNR',
#  'PBCT',
#  'PEP',
#  'PKI',
#  'PFE',
#  'PM',
#  'PSX',
#  'PNW',
#  'PXD',
#  'PNC',
#  'POOL',
#  'PPG',
#  'PPL',
#  'PFG',
#  'PG',
#  'PGR',
#  'PLD',
#  'PRU',
#  'PEG',
#  'PTC',
#  'PSA',
#  'PHM',
#  'PVH',
#  'QRVO',
#  'PWR',
#  'QCOM',
#  'DGX',
#  'RL',
#  'RJF',
#  'RTX',
#  'O',
#  'REG',
#  'REGN',
#  'RF',
#  'RSG',
#  'RMD',
#  'RHI',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RCL',
#  'SPGI',
#  'CRM',
#  'SBAC',
#  'SLB',
#  'STX',
#  'SEE',
#  'SRE',
#  'NOW',
#  'SHW',
#  'SBNY',
#  'SPG',
#  'SWKS',
#  'SNA',
#  'SEDG',
#  'SO',
#  'LUV',
#  'SWK',
#  'SBUX',
#  'STT',
#  'STE',
#  'SYK',
#  'SIVB',
#  'SYF',
#  'SNPS',
#  'SYY',
#  'TMUS',
#  'TROW',
#  'TTWO',
#  'TPR',
#  'TGT',
#  'TEL',
#  'TDY',
#  'TFX',
#  'TER',
#  'TSLA',
#  'TXN',
#  'TXT',
#  'TMO',
#  'TJX',
#  'TSCO',
#  'TT',
#  'TDG',
#  'TRV',
#  'TRMB',
#  'TFC',
#  'TWTR',
#  'TYL',
#  'TSN',
#  'UDR',
#  'ULTA',
#  'USB',
#  'UAA',
#  'UA',
#  'UNP',
#  'UAL',
#  'UNH',
#  'UPS',
#  'URI',
#  'UHS',
#  'VLO',
#  'VTR',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VFC',
#  'VIAC',
#  'VTRS',
#  'V',
#  'VNO',
#  'VMC',
#  'WRB',
#  'WAB',
#  'WMT',
#  'WBA',
#  'DIS',
#  'WM',
#  'WAT',
#  'WEC',
#  'WFC',
#  'WELL',
#  'WST',
#  'WDC',
#  'WRK',
#  'WY',
#  'WHR',
#  'WMB',
#  'WTW',
#  'WYNN',
#  'XEL',
#  'XLNX',
#  'XYL',
#  'YUM',
#  'ZBRA',
#  'ZBH',
#  'ZION',
#  'ZTS']

# %%
bad_tickers = []
import shutil
for t in tickers:
    csv_1 = '/Users/TyPainter1/Downloads/'
    csv_2 = t
    csv_3 = '.csv'
    csv_path = csv_1 + csv_2 + csv_3
    csv = csv_2 + csv_3
    destination = "/Users/TyPainter1/Desktop/Masters/spring-2022/capstone/00-data/stock_data/" + csv
    if exists(csv_path):
        shutil.move(csv_path, destination)
    elif exists(destination):
        pass
    else: 
        bad_tickers.append(t)

# %%
bad_tickers
# Out:
# ['ARE',
#  'BRK.B',
#  'BF.B',
#  'ECL',
#  'IPGP',
#  'LNC',
#  'NDAQ',
#  'NOC',
#  'PNC',
#  'PLD',
#  'DGX',
#  'RHI',
#  'ROP',
#  'SNA',
#  'STT',
#  'SIVB',
#  'SNPS',
#  'TMUS',
#  'TGT',
#  'TEL',
#  'TDY',
#  'TFX',
#  'TER',
#  'TSLA',
#  'TXN',
#  'TXT',
#  'TMO',
#  'TJX',
#  'TSCO',
#  'TT',
#  'TDG',
#  'TRV',
#  'TRMB',
#  'TFC',
#  'TWTR',
#  'TYL',
#  'TSN',
#  'UDR',
#  'ULTA',
#  'USB',
#  'UAA',
#  'UA',
#  'UNP',
#  'UAL',
#  'UNH',
#  'UPS',
#  'URI',
#  'UHS',
#  'VLO',
#  'VTR',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VFC',
#  'VIAC',
#  'VTRS',
#  'V',
#  'VNO',
#  'VMC',
#  'WRB',
#  'WAB',
#  'WMT',
#  'WBA',
#  'DIS',
#  'WM',
#  'WAT',
#  'WEC',
#  'WFC',
#  'WELL',
#  'WST',
#  'WDC',
#  'WRK',
#  'WY',
#  'WHR',
#  'WMB',
#  'WTW',
#  'WYNN',
#  'XEL',
#  'XLNX',
#  'XYL',
#  'YUM',
#  'ZBRA',
#  'ZBH',
#  'ZION',
#  'ZTS']

# %%
len(bad_tickers)
# Out:
# 86

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException

# comp_list = []
# for t in tickers:
#     driver = webdriver.Chrome(ChromeDriverManager().install())
#     url_1 = 'https://finance.yahoo.com/quote/'
#     url_2 = t
#     url_3 = '/history?period1=1609459200&period2=1640908800&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true'
#     url = url_1 + url_2 + url_3
#     driver.get(url)#put here the adress of your page
#     btn = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/div/div[3]/div[1]/div/div[2]/div/div/section/div[1]/div[2]/span[2]/a/span')
#     btn.click()
#     csv_1 = '/Users/TyPainter1/Downloads/'
#     csv_2 = t
#     csv_3 = '.csv'
#     csv = csv_1 + csv_2 + csv_3
#     comp_df = pd.read_csv(csv)
#     comp_df['Ticker'] = t
#     comp_list = comp_list.append(comp_df)
#     driver.close()
    
# df = pd.concat(comp_list, axis=0, ignore_index=True)

# %%
#from selenium import webdriver
from selenium.webdriver.chrome.service import Service
#from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

# %%
def stock_scrape(tickers):
    bad_xpath = []
    good_xpath = []
    counter = 0
    for t in bad_tickers:
        s=Service(ChromeDriverManager().install())
        driver = webdriver.Chrome(service=s)
        url_1 = 'https://finance.yahoo.com/quote/'
        url_2 = t
        url_3 = '/history?period1=1609459200&period2=1640908800&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true'
        url = url_1 + url_2 + url_3
        driver.get(url)# put here the adress of your page
        print(t)
        print(counter)
        counter+=1
        try:
            wait = WebDriverWait(driver, 20)
            element = wait.until(EC.element_to_be_clickable((By.XPATH,'/html/body/div[1]/div/div/div[1]/div/div[3]/div[1]/div/div[2]/div/div/section/div[1]/div[2]/span[2]/a/span')))
            btn = driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div[1]/div/div[3]/div[1]/div/div[2]/div/div/section/div[1]/div[2]/span[2]/a/span')
            #btn.click()
            element.click()
        except NoSuchElementException:  #spelling error making this code not work as expected
            bad_xpath.append(t)
            pass
        driver.close()
        
        csv_2 = t
        csv_3 = '.csv'
        csv = csv_2 + csv_3
        destination = "/Users/TyPainter1/Downloads/" + csv
        if exists(destination):
            good_xpath.append(t)
        else: 
            bad_xpath.append(t)
    
    return(good_xpath, bad_xpath)

# %%
tic = time.perf_counter()
######
good_tickers1, bad_tickers1 = stock_scrape(tickers)
#######
toc = time.perf_counter()
print(f"Runtime: {(toc - tic)/60:0.2f} minutes")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# ARE
# 0
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# BRK.B
# 1
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# BF.B
# 2
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# ECL
# 3
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# IPGP
# 4
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# LNC
# 5
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# NDAQ
# 6
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# NOC
# 7
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# PNC
# 8
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# PLD
# 9
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# DGX
# 10
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# RHI
# 11
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# ROP
# 12
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# SNA
# 13
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# STT
# 14
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# SIVB
# 15
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/TyPainter1/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-9-723cfd0f7e15> in <module>
#       1 tic = time.perf_counter()
#       2 ######
# ----> 3 good_tickers1, bad_tickers1 = stock_scrape(tickers)
#       4 #######
#       5 toc = time.perf_counter()
#
# <ipython-input-8-7afb53732a46> in stock_scrape(tickers)
#      10         url_3 = '/history?period1=1609459200&period2=1640908800&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true'
#      11         url = url_1 + url_2 + url_3
# ---> 12         driver.get(url)# put here the adress of your page
#      13         print(t)
#      14         print(counter)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     434         Loads a web page in the current browser session.
#     435         """
# --> 436         self.execute(Command.GET, {'url': url})
#     437
#     438     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: cannot determine loading status
# from disconnected: not connected to DevTools
#   (Session info: chrome=98.0.4758.80)
# Stacktrace:
# 0   chromedriver                        0x000000010ad9a3c9 chromedriver + 5018569
# 1   chromedriver                        0x000000010ad25333 chromedriver + 4539187
# 2   chromedriver                        0x000000010a8faa88 chromedriver + 170632
# 3   chromedriver                        0x000000010a8e5448 chromedriver + 83016
# 4   chromedriver                        0x000000010a8e5b4c chromedriver + 84812
# 5   chromedriver                        0x000000010a8f3912 chromedriver + 141586
# 6   chromedriver                        0x000000010a8f4202 chromedriver + 143874
# 7   chromedriver                        0x000000010a901933 chromedriver + 198963
# 8   chromedriver                        0x000000010a904a2a chromedriver + 211498
# 9   chromedriver                        0x000000010a8e5e6e chromedriver + 85614
# 10  chromedriver                        0x000000010a90156c chromedriver + 197996
# 11  chromedriver                        0x000000010a95fa13 chromedriver + 584211
# 12  chromedriver                        0x000000010a94c6d3 chromedriver + 505555
# 13  chromedriver                        0x000000010a92295e chromedriver + 334174
# 14  chromedriver                        0x000000010a923935 chromedriver + 338229
# 15  chromedriver                        0x000000010ad561ee chromedriver + 4739566
# 16  chromedriver                        0x000000010ad6ff51 chromedriver + 4845393
# 17  chromedriver                        0x000000010ad75928 chromedriver + 4868392
# 18  chromedriver                        0x000000010ad70a7a chromedriver + 4848250
# 19  chromedriver                        0x000000010ad4ac31 chromedriver + 4693041
# 20  chromedriver                        0x000000010ad8b978 chromedriver + 4958584
# 21  chromedriver                        0x000000010ad8bb01 chromedriver + 4958977
# 22  chromedriver                        0x000000010ada1795 chromedriver + 5048213
# 23  libsystem_pthread.dylib             0x00007ff807c144f4 _pthread_start + 125
# 24  libsystem_pthread.dylib             0x00007ff807c1000f thread_start + 15

# %%
print(good_tickers1)
print(bad_tickers1)

# %%
tic = time.perf_counter()
######
good_tickers2, bad_tickers2 = stock_scrape(bad_tickers1)
#######
toc = time.perf_counter()
print(f"Runtime: {(toc - tic)/60:0.2f} minutes")

# %%
print(good_tickers2)
print(bad_tickers2)
